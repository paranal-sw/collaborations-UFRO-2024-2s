# %% [markdown]
# # Command visualization app

# %% [markdown]
# Note: this notebook is also available in [Google Colaboratoy](https://colab.research.google.com/github/paranal-sw/collaborations-UFRO-2024-2s/blob/main/1-command-visualization/task_description.ipynb)
#
# The VLT Software has a mechanism to send command between processes. This is normally started in the instrument (PIONIER, MATISSE, GRAVITY) and in some cases like template ACQ or template OBS, the command is sent to subsystems (ISS, DL, ATx, ARAL, etc)
#
# It would be useful to have a graphical tool to understands who initiated the messages, the trip it makes through the systems, and included their parameters whenever is possible.
#
# ## Objective
# 1. Create a streamlit app to display command messages through processes.
# 1. Fill the gaps when commands send and receive are not clearly written.
# 1. Report the process to create the app and the assumtpioms made to fill the gaps.

# %% [markdown]
# Make a UML sequence diagram with the time(start and end) between process(if it fails or not), the instrument, the command(name) and the susbsystem(name),

# %% [markdown]
# ## Example app
#
# A sample streamlit app is provided to use as barebones. Please create subpages with different versions.
#
# To start the app:
#
# ```bash
# cd collaborations-UFRO-2024-2s
# source venv/bin/activate
#
# cd 1-command-visualization
# streamlit run Home_example1.py
# ```

# %%
import os 
import pandas as pd
from urllib.request import urlretrieve
REPO_URL='https://huggingface.co/datasets/Paranal/parlogs-observations/resolve/main/data'

if 'COLAB_RELEASE_TAG' in os.environ.keys():
    
    PATH='data/' # Convenient name to be Colab compatible
else:
    PATH='D:/Ufro/11 nivel/Lab modelacion 2/Trabajo_paramal/collaborations-UFRO-2024-2s/data' # Local directory to your system

def load_dataset(INSTRUMENT, RANGE):

    fname = f'{INSTRUMENT}-{RANGE}-traces.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_inst=pd.read_parquet(f'{PATH}/{fname}')

    fname = f'{INSTRUMENT}-{RANGE}-traces-SUBSYSTEMS.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_subs=pd.read_parquet(f'{PATH}/{fname}')

    fname = f'{INSTRUMENT}-{RANGE}-traces-TELESCOPES.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_tele=pd.read_parquet(f'{PATH}/{fname}')

    all_traces = [df_inst, df_subs, df_tele]

    df_all = pd.concat(all_traces)
    df_all.sort_values('@timestamp', inplace=True)
    df_all.reset_index(drop=True, inplace=True)

    return df_all

def load_trace(INSTRUMENT, RANGE, trace_id):
    df_all = load_dataset(INSTRUMENT, RANGE)
    df_all = df_all[ df_all['trace_id']==trace_id ]
    return df_all

def load_meta(INSTRUMENT, RANGE):
    fname = f'{INSTRUMENT}-{RANGE}-meta.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_meta=pd.read_parquet(f'{PATH}/{fname}')

    return df_meta

# %% [markdown]
# ## Example of command events

# %%
df_meta = load_meta("MATISSE", "1w")
df_meta
# Out:
#                       START                     END  TIMEOUT   system  \
# 0   2019-04-02 01:29:45.681 2019-04-02 01:38:08.541    False  MATISSE
# 1   2019-04-02 01:38:08.559 2019-04-02 01:44:02.506    False  MATISSE
# 2   2019-04-02 01:45:44.711 2019-04-02 01:58:00.921    False  MATISSE
# 3   2019-04-02 01:58:19.863 2019-04-02 02:14:00.315    False  MATISSE
# 4   2019-04-02 06:36:28.631 2019-04-02 07:00:16.566    False  MATISSE
# ..                      ...                     ...      ...      ...
# 215 2019-04-07 21:20:07.817 2019-04-07 21:22:12.808    False  MATISSE
# 216 2019-04-07 21:22:25.249 2019-04-07 21:34:42.495    False  MATISSE
# 217 2019-04-07 21:34:42.495 2019-04-07 21:39:06.173    False  MATISSE
# 218 2019-04-07 21:40:15.747 2019-04-07 21:42:02.235    False  MATISSE
# 219 2019-04-07 21:42:20.993 2019-04-07 21:44:06.241    False  MATISSE
#
#     procname                         TPL_ID  ERROR  Aborted  SECONDS TEL
# 0    bob_ins                MATISSE_img_acq  False    False    502.0  AT
# 1    bob_ins                MATISSE_hyb_obs  False    False    353.0  AT
# 2    bob_ins                MATISSE_img_acq  False    False    736.0  AT
# 3    bob_ins                MATISSE_hyb_obs  False    False    940.0  AT
# 4    bob_ins                MATISSE_img_acq  False    False   1427.0  AT
# ..       ...                            ...    ...      ...      ...  ..
# 215  bob_ins            MATISSE_gen_tec_opd  False    False    124.0  AT
# 216  bob_ins  MATISSE_gen_tec_check_fringes  False    False    737.0  AT
# 217  bob_ins           MATISSE_gen_cal_bias  False    False    263.0  AT
# 218  bob_ins           MATISSE_gen_cal_bias  False    False    106.0  AT
# 219  bob_ins           MATISSE_gen_cal_bias  False    False    105.0  AT
#
# [220 rows x 10 columns]

# %%
df_meta['Aborted'].value_counts()
# Out:
# Aborted
# False    201
# True      19
# Name: count, dtype: int64

# %%
df_meta['ERROR'].value_counts()
# Out:
# ERROR
# False    214
# True       6
# Name: count, dtype: int64

# %%
df_meta['TIMEOUT'].value_counts()
# Out:
# TIMEOUT
# False    220
# Name: count, dtype: int64

# %%
df_meta['TEL'].value_counts()
# Out:
# TEL
# AT    220
# Name: count, dtype: int64

# %%
df_meta['TPL_ID'].value_counts()
# Out:
# TPL_ID
# MATISSE_img_acq                  43
# MATISSE_gen_tec_opd              42
# MATISSE_hyb_obs                  26
# MATISSE_gen_cal_bias             21
# MATISSE_gen_cal_imbasic          18
# MATISSE_gen_cal_det_h2           17
# MATISSE_gen_cal_shift            16
# MATISSE_gen_cal_transfunc         6
# MATISSE_gen_tec_standby           6
# MATISSE_gen_tec_ali               6
# MATISSE_gen_cal_kappa             6
# MATISSE_gen_tec_check_fringes     5
# CALOB_gen_tec_log                 3
# MATISSE_gen_cal_det_aq            2
# MATISSE_gen_cal_imrem             2
# MATISSE_gen_cal_imext             1
# Name: count, dtype: int64

# %%
df_trace = load_trace("MATISSE", "1w", 0)
df_trace = df_trace[['@timestamp', 'system', 'procname', 'logtext', 'trace_id']]

# %% [markdown]
# ### Search *command*

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_trace[ df_trace['logtext'].str.contains("command") ][:50])
# Out:
#                  @timestamp   system      procname  \
# 131 2019-04-02 01:29:47.435  MATISSE    mtoControl
# 135 2019-04-02 01:29:47.440  MATISSE    mtoControl
# 138 2019-04-02 01:29:47.696  MATISSE    mtoControl
# 164 2019-04-02 01:30:09.566  MATISSE    mtoControl
# 167 2019-04-02 01:30:09.567  MATISSE    mtoControl
# 172 2019-04-02 01:30:11.165  MATISSE    mtoControl
# 175 2019-04-02 01:30:11.166  MATISSE    mtoControl
# 180 2019-04-02 01:30:13.374  MATISSE    mtoControl
# 182 2019-04-02 01:30:13.397  MATISSE       bob_ins
# 183 2019-04-02 01:30:13.418      ISS  issifControl
# 184 2019-04-02 01:30:13.419  MATISSE       bob_ins
# 185 2019-04-02 01:30:13.482      ISS  issifControl
# 194 2019-04-02 01:30:14.440  MATISSE       bob_ins
# 196 2019-04-02 01:30:14.451  MATISSE       bob_ins
# 197 2019-04-02 01:30:14.456  MATISSE       bob_ins
# 198 2019-04-02 01:30:14.456      ISS  issifControl
# 199 2019-04-02 01:30:14.457      ISS  issifControl
# 200 2019-04-02 01:30:14.460  MATISSE       bob_ins
# 202 2019-04-02 01:30:14.472  MATISSE       bob_ins
# 203 2019-04-02 01:30:14.477      ISS  issifControl
# 204 2019-04-02 01:30:14.478  MATISSE       bob_ins
# 205 2019-04-02 01:30:14.482      ISS  issifControl
# 207 2019-04-02 01:30:15.482  MATISSE       bob_ins
# 208 2019-04-02 01:30:15.483  MATISSE       bob_ins
# 209 2019-04-02 01:30:15.485  MATISSE       bob_ins
# 210 2019-04-02 01:30:15.485      ISS  issifControl
# 211 2019-04-02 01:30:15.490      ISS  issifControl
# 212 2019-04-02 01:30:15.494  MATISSE       bob_ins
# 214 2019-04-02 01:30:15.498  MATISSE       bob_ins
# 215 2019-04-02 01:30:15.499      ISS  issifControl
# 216 2019-04-02 01:30:15.499  MATISSE       bob_ins
# 217 2019-04-02 01:30:15.503      ISS  issifControl
# 218 2019-04-02 01:30:16.502  MATISSE       bob_ins
# 220 2019-04-02 01:30:16.506  MATISSE       bob_ins
# 221 2019-04-02 01:30:16.513      ISS  issifControl
# 222 2019-04-02 01:30:16.514  MATISSE       bob_ins
# 223 2019-04-02 01:30:16.519      ISS  issifControl
# 226 2019-04-02 01:30:17.517  MATISSE       bob_ins
# 228 2019-04-02 01:30:17.520  MATISSE       bob_ins
# 229 2019-04-02 01:30:17.522      ISS  issifControl
# 230 2019-04-02 01:30:17.522  MATISSE       bob_ins
# 231 2019-04-02 01:30:17.524      ISS  issifControl
# 232 2019-04-02 01:30:17.532  MATISSE       bob_ins
# 233 2019-04-02 01:30:17.534  MATISSE    mtoControl
# 237 2019-04-02 01:30:17.659  MATISSE    mtoControl
# 241 2019-04-02 01:30:17.668  MATISSE       bob_ins
# 242 2019-04-02 01:30:17.670  MATISSE       bob_ins
# 243 2019-04-02 01:30:17.670      ISS  issifControl
# 244 2019-04-02 01:30:17.672      AT1    prsControl
# 245 2019-04-02 01:30:17.672      AT1   atifControl
#
#                                                                                       logtext  \
# 131                                                               Executing SETUP command ...
# 135                                                                       SETUP command done.
# 138                                                               Executing SETUP command ...
# 164                                                                       SETUP command done.
# 167                                                               Executing SETUP command ...
# 172                                                                       SETUP command done.
# 175                                                               Executing SETUP command ...
# 180                                                                       SETUP command done.
# 182      Send command CHKMOON 064508.910,-164258.000,0.0 to process issifControl env. wvgvlti
# 183                     CDP   : Received command: CHKMOON, Buffer: 064508.910,-164258.000,0.0
# 184                    Waiting (timeout 40000) for pending replies to command CHKMOON id cmd0
# 185                                CDP   : Succesfully completed command: CHKMOON, Buffer: OK
# 194                                            Last reply to command CHKMOON id cmd0 received
# 196                                 Send command GETIAS  to process issifControl env. wvgvlti
# 197                     Waiting (timeout 40000) for pending replies to command GETIAS id cmd0
# 198                                                 CDP   : Received command: GETIAS, Buffer:
# 199                               CDP   : Succesfully completed command: GETIAS, Buffer: IRIS
# 200                                             Last reply to command GETIAS id cmd0 received
# 202   Send command SETPOF MATISSE,1,-0.727000,-66.593000 to process issifControl env. wvgvlti
# 203                  CDP   : Received command: SETPOF, Buffer: MATISSE,1,-0.727000,-66.593000
# 204                     Waiting (timeout 60000) for pending replies to command SETPOF id cmd0
# 205                                 CDP   : Succesfully completed command: SETPOF, Buffer: OK
# 207                                             Last reply to command SETPOF id cmd0 received
# 208  Send command SETPOF MATISSE,2,-24.100000,-19.163000 to process issifControl env. wvgvlti
# 209                     Waiting (timeout 60000) for pending replies to command SETPOF id cmd0
# 210                 CDP   : Received command: SETPOF, Buffer: MATISSE,2,-24.100000,-19.163000
# 211                                 CDP   : Succesfully completed command: SETPOF, Buffer: OK
# 212                                             Last reply to command SETPOF id cmd0 received
# 214     Send command SETPOF MATISSE,3,51.852000,3.193000 to process issifControl env. wvgvlti
# 215                    CDP   : Received command: SETPOF, Buffer: MATISSE,3,51.852000,3.193000
# 216                     Waiting (timeout 60000) for pending replies to command SETPOF id cmd0
# 217                                 CDP   : Succesfully completed command: SETPOF, Buffer: OK
# 218                                             Last reply to command SETPOF id cmd0 received
# 220   Send command SETPOF MATISSE,4,-0.185000,-15.348000 to process issifControl env. wvgvlti
# 221                  CDP   : Received command: SETPOF, Buffer: MATISSE,4,-0.185000,-15.348000
# 222                     Waiting (timeout 60000) for pending replies to command SETPOF id cmd0
# 223                                 CDP   : Succesfully completed command: SETPOF, Buffer: OK
# 226                                             Last reply to command SETPOF id cmd0 received
# 228                         Send command SETTADC ENABLED to process issifControl env. wvgvlti
# 229                                        CDP   : Received command: SETTADC, Buffer: ENABLED
# 230                    Waiting (timeout 15000) for pending replies to command SETTADC id cmd0
# 231                                CDP   : Succesfully completed command: SETTADC, Buffer: OK
# 232                                            Last reply to command SETTADC id cmd0 received
# 233                                                               Executing SETUP command ...
# 237                                                                       SETUP command done.
# 241                                 Send command CLRSTP  to process issifControl env. wvgvlti
# 242                     Waiting (timeout 15000) for pending replies to command CLRSTP id cmd0
# 243                                                 CDP   : Received command: CLRSTP, Buffer:
# 244                                                 PRESET: Received command: CLRSTP, Buffer:
# 245                                                 TIF   : Received command: CLRSTP, Buffer:
#
#      trace_id
# 131         0
# 135         0
# 138         0
# 164         0
# 167         0
# 172         0
# 175         0
# 180         0
# 182         0
# 183         0
# 184         0
# 185         0
# 194         0
# 196         0
# 197         0
# 198         0
# 199         0
# 200         0
# 202         0
# 203         0
# 204         0
# 205         0
# 207         0
# 208         0
# 209         0
# 210         0
# 211         0
# 212         0
# 214         0
# 215         0
# 216         0
# 217         0
# 218         0
# 220         0
# 221         0
# 222         0
# 223         0
# 226         0
# 228         0
# 229         0
# 230         0
# 231         0
# 232         0
# 233         0
# 237         0
# 241         0
# 242         0
# 243         0
# 244         0
# 245         0

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_trace[ df_trace['logtext'].str.contains("CHKMOON") ][:50])
# Out:
#                  @timestamp   system      procname  \
# 182 2019-04-02 01:30:13.397  MATISSE       bob_ins
# 183 2019-04-02 01:30:13.418      ISS  issifControl
# 184 2019-04-02 01:30:13.419  MATISSE       bob_ins
# 185 2019-04-02 01:30:13.482      ISS  issifControl
# 194 2019-04-02 01:30:14.440  MATISSE       bob_ins
#
#                                                                                   logtext  \
# 182  Send command CHKMOON 064508.910,-164258.000,0.0 to process issifControl env. wvgvlti
# 183                 CDP   : Received command: CHKMOON, Buffer: 064508.910,-164258.000,0.0
# 184                Waiting (timeout 40000) for pending replies to command CHKMOON id cmd0
# 185                            CDP   : Succesfully completed command: CHKMOON, Buffer: OK
# 194                                        Last reply to command CHKMOON id cmd0 received
#
#      trace_id
# 182         0
# 183         0
# 184         0
# 185         0
# 194         0

# %%
df_tratamiento=df_trace[ df_trace['logtext'].str.contains("CHKMOON") ][:]
#print(df_tratamiento['system'])
#print(df_tratamiento['procname'])
#print(df_tratamiento[0:1]['system'])
df_tratamiento.head()
# Out:
#                  @timestamp   system      procname  \
# 182 2019-04-02 01:30:13.397  MATISSE       bob_ins
# 183 2019-04-02 01:30:13.418      ISS  issifControl
# 184 2019-04-02 01:30:13.419  MATISSE       bob_ins
# 185 2019-04-02 01:30:13.482      ISS  issifControl
# 194 2019-04-02 01:30:14.440  MATISSE       bob_ins
#
#                                                logtext  trace_id
# 182  Send command CHKMOON 064508.910,-164258.000,0....         0
# 183  CDP   : Received command: CHKMOON, Buffer: 064...         0
# 184  Waiting (timeout 40000) for pending replies to...         0
# 185  CDP   : Succesfully completed command: CHKMOON...         0
# 194     Last reply to command CHKMOON id cmd0 received         0

# %%
df_tratamiento[df_tratamiento['logtext'].str.contains("Send")]['system']
# Out:
# 182    MATISSE
# Name: system, dtype: object

# %%
df_tratamiento[df_tratamiento['logtext'].str.contains("Received command")]['system']
# Out:
# 183    ISS
# Name: system, dtype: object

# %%
df_tratamiento[df_tratamiento['logtext'].str.contains("Waiting")]['system']
# Out:
# 184    MATISSE
# Name: system, dtype: object

# %%
df_tratamiento[df_tratamiento['logtext'].str.contains("Succesfully completed")]['system']
# Out:
# 185    ISS
# Name: system, dtype: object

# %%
df_tratamiento[df_tratamiento['logtext'].str.contains("Last reply")]['system']
# Out:
# 194    MATISSE
# Name: system, dtype: object

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_trace[ df_trace['logtext'].str.contains("CLRSTP") ][:])
# Out:
#                   @timestamp   system       procname  \
# 241  2019-04-02 01:30:17.668  MATISSE        bob_ins
# 242  2019-04-02 01:30:17.670  MATISSE        bob_ins
# 243  2019-04-02 01:30:17.670      ISS   issifControl
# 244  2019-04-02 01:30:17.672      AT1     prsControl
# 245  2019-04-02 01:30:17.672      AT1    atifControl
# 246  2019-04-02 01:30:17.673      AT2     prsControl
# 247  2019-04-02 01:30:17.673      AT2    atifControl
# 248  2019-04-02 01:30:17.675      AT3     prsControl
# 249  2019-04-02 01:30:17.675      AT3    atifControl
# 250  2019-04-02 01:30:17.676      AT4    atifControl
# 251  2019-04-02 01:30:17.676      AT4     prsControl
# 252  2019-04-02 01:30:17.677       DL   dlprsControl
# 253  2019-04-02 01:30:17.677      ISS  issprsControl
# 254  2019-04-02 01:30:17.677       DL    dlifControl
# 255  2019-04-02 01:30:17.681       DL   dlprsControl
# 256  2019-04-02 01:30:17.681       DL    dlifControl
# 257  2019-04-02 01:30:17.684      ISS  issprsControl
# 259  2019-04-02 01:30:17.736      AT3    atifControl
# 261  2019-04-02 01:30:17.741      AT2    atifControl
# 262  2019-04-02 01:30:17.747      AT1    atifControl
# 264  2019-04-02 01:30:17.757      AT4    atifControl
# 266  2019-04-02 01:30:17.759      ISS   issifControl
# 269  2019-04-02 01:30:18.673  MATISSE        bob_ins
# 1721 2019-04-02 01:34:58.122      AT3     prsControl
#
#                                                                     logtext  \
# 241               Send command CLRSTP  to process issifControl env. wvgvlti
# 242   Waiting (timeout 15000) for pending replies to command CLRSTP id cmd0
# 243                               CDP   : Received command: CLRSTP, Buffer:
# 244                               PRESET: Received command: CLRSTP, Buffer:
# 245                               TIF   : Received command: CLRSTP, Buffer:
# 246                               PRESET: Received command: CLRSTP, Buffer:
# 247                               TIF   : Received command: CLRSTP, Buffer:
# 248                               PRESET: Received command: CLRSTP, Buffer:
# 249                               TIF   : Received command: CLRSTP, Buffer:
# 250                               TIF   : Received command: CLRSTP, Buffer:
# 251                               PRESET: Received command: CLRSTP, Buffer:
# 252                               PRESET: Received command: CLRSTP, Buffer:
# 253                              CONTROL: Received command: CLRSTP, Buffer:
# 254                               TIF   : Received command: CLRSTP, Buffer:
# 255                   PRESET: Command CLRSTP (NoMove) succesfully completed
# 256               TIF   : Succesfully completed command: CLRSTP, Buffer: OK
# 257                  CONTROL: Command CLRSTP (NoMove) succesfully completed
# 259               TIF   : Succesfully completed command: CLRSTP, Buffer: OK
# 261               TIF   : Succesfully completed command: CLRSTP, Buffer: OK
# 262               TIF   : Succesfully completed command: CLRSTP, Buffer: OK
# 264               TIF   : Succesfully completed command: CLRSTP, Buffer: OK
# 266               CDP   : Succesfully completed command: CLRSTP, Buffer: OK
# 269                           Last reply to command CLRSTP id cmd0 received
# 1721                              PRESET: Received command: CLRSTP, Buffer:
#
#       trace_id
# 241          0
# 242          0
# 243          0
# 244          0
# 245          0
# 246          0
# 247          0
# 248          0
# 249          0
# 250          0
# 251          0
# 252          0
# 253          0
# 254          0
# 255          0
# 256          0
# 257          0
# 259          0
# 261          0
# 262          0
# 264          0
# 266          0
# 269          0
# 1721         0

# %% [markdown]
# ### List of commands
#
# This method must be double checked

# %%
cmd = df_trace[ df_trace['logtext'].str.contains("command")]['logtext']

# Please replace this with an elegant regexp!
cmd = cmd.apply(lambda x: x.replace(":", " "))
cmd = cmd.apply(lambda x: x.replace(",", " "))
cmd = cmd.apply(lambda x: x.replace("'", " "))
cmd = cmd.apply(lambda x: x.replace("  ", " "))

cmdlist = []
for x in cmd:
    splitted = x.split()
    # print(splitted)
    if "command" in splitted:
        idx = splitted.index("command")
        command = splitted[idx+1]
        if command not in ["...", "done.", "to"]:
            cmdlist.append(command)
set(cmdlist)
# Out:
# {'CHKMOON',
#  'CLRSTP',
#  'GETCONF',
#  'GETDEL',
#  'GETDELD',
#  'GETIAS',
#  'PRABS',
#  'PRCHK',
#  'PRESET',
#  'PRSCOOR',
#  'PRSNAME',
#  'PRTOGS',
#  'SETBEAM',
#  'SETPOF',
#  'SETREF',
#  'SETTADC',
#  'SETUP',
#  'STOPAG',
#  'STOPCAG',
#  'STOPCHP',
#  'STOPLAG',
#  'STRTLAG'}

# %% [markdown]
# ### Search *SETUP*

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_trace[ df_trace['logtext'].str.contains("SETUP") ][:])
# Out:
#                   @timestamp   system    procname  \
# 130  2019-04-02 01:29:47.434  MATISSE     bob_ins
# 131  2019-04-02 01:29:47.435  MATISSE  mtoControl
# 132  2019-04-02 01:29:47.436  MATISSE  mtoControl
# 133  2019-04-02 01:29:47.436  MATISSE  mtoControl
# 135  2019-04-02 01:29:47.440  MATISSE  mtoControl
# ...                      ...      ...         ...
# 2359 2019-04-02 01:38:00.099  MATISSE  mtoControl
# 2373 2019-04-02 01:38:00.488  MATISSE  mtoControl
# 2374 2019-04-02 01:38:00.489  MATISSE     bob_ins
# 2377 2019-04-02 01:38:00.489  MATISSE  mtoControl
# 2405 2019-04-02 01:38:08.522  MATISSE  mtoControl
#
#                                                                                                                                                               logtext  \
# 130                                                                                             SETUP -noExposure -function DET1.START.VAL 1  DET2.START.VAL 1 (blue)
# 131                                                                                                                                       Executing SETUP command ...
# 132                                                                                                                                        Forward(b) SETUP to NGCIR1
# 133                                                                                                                                        Forward(b) SETUP to NGCIR2
# 135                                                                                                                                               SETUP command done.
# ...                                                                                                                                                               ...
# 2359                                                                                                                                      Executing SETUP command ...
# 2373                                                                                                                                              SETUP command done.
# 2374  SETUP -noExposure -function INS.SOS1.NAME OUT INS.SOS2.NAME OUT INS.BCD1.NAME OUT INS.BCD2.NAME OUT INS.OML1.OPD 0 INS.OML2.OPD 0 INS.OML3.OPD 0 INS.OML4.OPD 0
# 2377                                                                                                                                      Executing SETUP command ...
# 2405                                                                                                                                              SETUP command done.
#
#       trace_id
# 130          0
# 131          0
# 132          0
# 133          0
# 135          0
# ...        ...
# 2359         0
# 2373         0
# 2374         0
# 2377         0
# 2405         0
#
# [109 rows x 5 columns]

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_trace[ df_trace['logtext'].str.contains("SETUP command") ][:50])
# Out:
#                   @timestamp   system       procname  \
# 131  2019-04-02 01:29:47.435  MATISSE     mtoControl
# 135  2019-04-02 01:29:47.440  MATISSE     mtoControl
# 138  2019-04-02 01:29:47.696  MATISSE     mtoControl
# 164  2019-04-02 01:30:09.566  MATISSE     mtoControl
# 167  2019-04-02 01:30:09.567  MATISSE     mtoControl
# 172  2019-04-02 01:30:11.165  MATISSE     mtoControl
# 175  2019-04-02 01:30:11.166  MATISSE     mtoControl
# 180  2019-04-02 01:30:13.374  MATISSE     mtoControl
# 233  2019-04-02 01:30:17.534  MATISSE     mtoControl
# 237  2019-04-02 01:30:17.659  MATISSE     mtoControl
# 362  2019-04-02 01:30:19.787  MATISSE     mtoControl
# 403  2019-04-02 01:30:20.232     ARAL     aroControl
# 405  2019-04-02 01:30:20.238     ARAL  iriswsControl
# 406  2019-04-02 01:30:20.240     ARAL  iriswsControl
# 408  2019-04-02 01:30:20.242     ARAL     aroControl
# 871  2019-04-02 01:30:29.195  MATISSE     mtoControl
# 2317 2019-04-02 01:37:59.274  MATISSE     mtoControl
# 2337 2019-04-02 01:38:00.070  MATISSE     mtoControl
# 2341 2019-04-02 01:38:00.073  MATISSE     mtoControl
# 2344 2019-04-02 01:38:00.078  MATISSE     mtoControl
# 2348 2019-04-02 01:38:00.083  MATISSE     mtoControl
# 2351 2019-04-02 01:38:00.089  MATISSE     mtoControl
# 2359 2019-04-02 01:38:00.099  MATISSE     mtoControl
# 2373 2019-04-02 01:38:00.488  MATISSE     mtoControl
# 2377 2019-04-02 01:38:00.489  MATISSE     mtoControl
# 2405 2019-04-02 01:38:08.522  MATISSE     mtoControl
#
#                           logtext  trace_id
# 131   Executing SETUP command ...         0
# 135           SETUP command done.         0
# 138   Executing SETUP command ...         0
# 164           SETUP command done.         0
# 167   Executing SETUP command ...         0
# 172           SETUP command done.         0
# 175   Executing SETUP command ...         0
# 180           SETUP command done.         0
# 233   Executing SETUP command ...         0
# 237           SETUP command done.         0
# 362   Executing SETUP command ...         0
# 403   Executing SETUP command ...         0
# 405   Executing SETUP command ...         0
# 406           SETUP command done.         0
# 408           SETUP command done.         0
# 871           SETUP command done.         0
# 2317  Executing SETUP command ...         0
# 2337          SETUP command done.         0
# 2341  Executing SETUP command ...         0
# 2344          SETUP command done.         0
# 2348  Executing SETUP command ...         0
# 2351          SETUP command done.         0
# 2359  Executing SETUP command ...         0
# 2373          SETUP command done.         0
# 2377  Executing SETUP command ...         0
# 2405          SETUP command done.         0

# %% [markdown]
# ### Search *PRESET*

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_trace[ df_trace['logtext'].str.contains("PRESET") ][:59])
# Out:
#                   @timestamp   system      procname  \
# 79   2019-04-02 01:29:45.947  MATISSE       bob_ins
# 244  2019-04-02 01:30:17.672      AT1    prsControl
# 246  2019-04-02 01:30:17.673      AT2    prsControl
# 248  2019-04-02 01:30:17.675      AT3    prsControl
# 251  2019-04-02 01:30:17.676      AT4    prsControl
# 252  2019-04-02 01:30:17.677       DL  dlprsControl
# 255  2019-04-02 01:30:17.681       DL  dlprsControl
# 258  2019-04-02 01:30:17.736      AT3    prsControl
# 260  2019-04-02 01:30:17.741      AT2    prsControl
# 263  2019-04-02 01:30:17.747      AT1    prsControl
# 265  2019-04-02 01:30:17.757      AT4    prsControl
# 338  2019-04-02 01:30:19.761      ISS  issprsAction
# 392  2019-04-02 01:30:20.187      ISS  issprsAction
# 395  2019-04-02 01:30:20.224      AT1    prsControl
# 396  2019-04-02 01:30:20.225      AT2    prsControl
# 398  2019-04-02 01:30:20.227      AT3    prsControl
# 400  2019-04-02 01:30:20.229      AT4    prsControl
# 402  2019-04-02 01:30:20.231       DL  dlprsControl
# 417  2019-04-02 01:30:20.244      AT2   pscsControl
# 436  2019-04-02 01:30:20.245      AT1   pscsControl
# 450  2019-04-02 01:30:20.246      AT3   pscsControl
# 473  2019-04-02 01:30:20.247      AT4   pscsControl
# 676  2019-04-02 01:30:21.732      AT2  nmmgrControl
# 697  2019-04-02 01:30:21.736      AT1  nmmgrControl
# 713  2019-04-02 01:30:21.738      AT4  nmmgrControl
# 737  2019-04-02 01:30:21.741      AT3  nmmgrControl
# 781  2019-04-02 01:30:25.266       DL   dlprsAction
# 924  2019-04-02 01:31:13.463       DL  dlprsControl
# 1355 2019-04-02 01:33:08.295      AT3    prsControl
# 1426 2019-04-02 01:33:20.065      AT4    prsControl
# 1432 2019-04-02 01:33:20.835      AT1    prsControl
# 1450 2019-04-02 01:33:24.927      AT2    prsControl
# 1721 2019-04-02 01:34:58.122      AT3    prsControl
# 1722 2019-04-02 01:34:58.127      AT3    prsControl
# 1726 2019-04-02 01:34:59.298      AT3    prsControl
# 1727 2019-04-02 01:34:59.300      AT3    prsControl
# 1728 2019-04-02 01:34:59.300      AT3    prsControl
# 1729 2019-04-02 01:34:59.311      AT3    prsControl
# 1730 2019-04-02 01:34:59.311      AT3    prsControl
# 1731 2019-04-02 01:34:59.313      AT3    prsControl
# 1732 2019-04-02 01:34:59.314      AT3    prsControl
# 1749 2019-04-02 01:34:59.325      AT3   pscsControl
# 1835 2019-04-02 01:35:00.824      AT3  nmmgrControl
# 2127 2019-04-02 01:37:19.564      AT3    prsControl
#
#                                                                                                                                                                               logtext  \
# 79                                                                                                                                                                SEQ PRESET ST = 'T'
# 244                                                                                                                                         PRESET: Received command: CLRSTP, Buffer:
# 246                                                                                                                                         PRESET: Received command: CLRSTP, Buffer:
# 248                                                                                                                                         PRESET: Received command: CLRSTP, Buffer:
# 251                                                                                                                                         PRESET: Received command: CLRSTP, Buffer:
# 252                                                                                                                                         PRESET: Received command: CLRSTP, Buffer:
# 255                                                                                                                             PRESET: Command CLRSTP (NoMove) succesfully completed
# 258                                                                                                                            PRESET: Command STOPTRK (NoMove) succesfully completed
# 260                                                                                                                            PRESET: Command STOPTRK (NoMove) succesfully completed
# 263                                                                                                                            PRESET: Command STOPTRK (NoMove) succesfully completed
# 265                                                                                                                            PRESET: Command STOPTRK (NoMove) succesfully completed
# 338                                                                            ACTION: Received command: PRESET, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 64508.910 TEL.TARG
# 392                                                                                                                           ACTION: Send command to issmswControl : PRESET, Buffer:
# 395                                                                             PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 64508.562 TEL.TARG
# 396                                                                             PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 64508.562 TEL.TARG
# 398                                                                             PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 64508.562 TEL.TARG
# 400                                                                             PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 64508.562 TEL.TARG
# 402              PRESET: Received command: SETUP, Buffer: ,,DEL.TARG.TYPE OBJ_COORD TEL.TARG.ALPHA 64508.910 TEL.TARG.DELTA -164258.000 TEL.TARG.EPOCH 2000.000 TEL.TARG.EPOCHSYST...
# 417   0 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" TEL
# 436   0 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" TEL
# 450   0 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" TEL
# 473   0 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" TEL
# 676   0 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" TEL
# 697   0 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" TEL
# 713   0 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" TEL
# 737   0 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" TEL
# 781                                                                                                                                        PRESET: All tracking VCMs within tolerance
# 924                                                               PRESET: Succesfully completed. Command: SETUP, Buffer: ,,DEL.TARG.TYPE OBJ_COORD TEL.TARG.ALPHA 64508.910 TEL.TARG.
# 1355                                                              PRESET: Succesfully completed. Command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 64508.562 TEL.TARG
# 1426                                                              PRESET: Succesfully completed. Command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 64508.562 TEL.TARG
# 1432                                                              PRESET: Succesfully completed. Command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 64508.562 TEL.TARG
# 1450                                                              PRESET: Succesfully completed. Command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 64508.562 TEL.TARG
# 1721                                                                                                                                        PRESET: Received command: CLRSTP, Buffer:
# 1722                                                                                                                           PRESET: Command STOPTRK (NoMove) succesfully completed
# 1726                                                                                                    PRESET: Received command: SETUP, Buffer: ,,COU.AG.GSSOURCE SCIENCE,TRUE,FALSE
# 1727                                                                                                                           PRESET: Command STOPTRK (NoMove) succesfully completed
# 1728                                                                                                       PRESET: Received command: SETUP, Buffer: ,prsCurrentSetup.targ,,TRUE,FALSE
# 1729                                                                                                                           PRESET: Command STOPTRK (NoMove) succesfully completed
# 1730                                                                                       PRESET: Received command: SETUP, Buffer: ,,ISS.PRI.PRESET.TYPE MEASUREMENT_SWAP,TRUE,FALSE
# 1731                                                                                                                           PRESET: Command STOPTRK (NoMove) succesfully completed
# 1732                                                                          PRESET: Received command: PRSCOOR, Buffer: 64508.562,-164258,J,2000,2000,-0.546,-1.22,0,0,M,3150,0.0,0.
# 1749  0 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" TEL
# 1835  0 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" TEL
# 2127                                                            PRESET: Succesfully completed. Command: PRSCOOR, Buffer: 64508.562,-164258,J,2000,2000,-0.546,-1.22,0,0,M,3150,0.0,0.
#
#       trace_id
# 79           0
# 244          0
# 246          0
# 248          0
# 251          0
# 252          0
# 255          0
# 258          0
# 260          0
# 263          0
# 265          0
# 338          0
# 392          0
# 395          0
# 396          0
# 398          0
# 400          0
# 402          0
# 417          0
# 436          0
# 450          0
# 473          0
# 676          0
# 697          0
# 713          0
# 737          0
# 781          0
# 924          0
# 1355         0
# 1426         0
# 1432         0
# 1450         0
# 1721         0
# 1722         0
# 1726         0
# 1727         0
# 1728         0
# 1729         0
# 1730         0
# 1731         0
# 1732         0
# 1749         0
# 1835         0
# 2127         0

# %%
# import pandas as pd
# # the location of the files data
# file_path = 'D:/Ufro/11 nivel/Lab modelacion 2/Trabajo_paramal/collaborations-UFRO-2024-2s/data/PIONIER-1w-meta.parket'
# # read the dataframe from the parquet file
# df = pd.read_parquet(file_path)
# df

# %%
# df_meta = load_meta("PIONIER", "1w")
# df_meta

# %%
df_trace1=df_trace[df_trace['logtext'].str.contains("")][0:1000]
df_trace1.to_excel('df_trace1.xlsx')

# %%
import os 
import pandas as pd
from urllib.request import urlretrieve
REPO_URL='https://huggingface.co/datasets/Paranal/parlogs-observations/resolve/main/data'

if 'COLAB_RELEASE_TAG' in os.environ.keys():
    PATH='data/' # Convenient name to be Colab compatible
else:
    PATH='D:/Ufro/11 nivel/Lab modelacion 2/Trabajo_paramal/collaborations-UFRO-2024-2s/data' # Local directory to your system

def load_dataset(INSTRUMENT, RANGE):
    fname = f'{INSTRUMENT}-{RANGE}-traces.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_inst = pd.read_parquet(f'{PATH}/{fname}')

    fname = f'{INSTRUMENT}-{RANGE}-traces-SUBSYSTEMS.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_subs = pd.read_parquet(f'{PATH}/{fname}')

    fname = f'{INSTRUMENT}-{RANGE}-traces-TELESCOPES.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_tele = pd.read_parquet(f'{PATH}/{fname}')

    all_traces = [df_inst, df_subs, df_tele]

    df_all = pd.concat(all_traces)
    df_all.sort_values('@timestamp', inplace=True)
    df_all.reset_index(drop=True, inplace=True)

    return df_all

def load_all_traces(RANGE):
    instruments = ["MATISSE", "PIONIER", "GRAVITY"]  # Añade todos los instrumentos aquí
    all_dfs = []
    for instrument in instruments:
        df_all = load_dataset(instrument, RANGE)
        all_dfs.append(df_all)
    
    df_all_instruments = pd.concat(all_dfs)
    df_all_instruments.sort_values('@timestamp', inplace=True)
    df_all_instruments.reset_index(drop=True, inplace=True)
    
    return df_all_instruments

def load_trace(INSTRUMENT, RANGE, trace_id):
    df_all = load_dataset(INSTRUMENT, RANGE)
    df_all = df_all[ df_all['trace_id']==trace_id ]
    return df_all


def load_meta(INSTRUMENT, RANGE):
    fname = f'{INSTRUMENT}-{RANGE}-meta.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_meta = pd.read_parquet(f'{PATH}/{fname}')

    return df_meta

# %%
df_trace = load_all_traces( "1w")
df_trace = df_trace[['@timestamp', 'system', 'procname', 'logtext', 'trace_id']]

with pd.option_context('display.max_colwidth', None):
    display(df_trace[df_trace['@timestamp'].between('2019-04-02 00:00:00', '2019-04-07 23:59:59')])
#df_trace.to_excel('trace.xlsx')
# Out:
#                      @timestamp   system   procname  \
# 43      2019-04-02 01:29:45.681  MATISSE    bob_ins
# 44      2019-04-02 01:29:45.681  MATISSE    bob_ins
# 45      2019-04-02 01:29:45.945  MATISSE    bob_ins
# 46      2019-04-02 01:29:45.945  MATISSE    bob_ins
# 47      2019-04-02 01:29:45.945  MATISSE    bob_ins
# ...                         ...      ...        ...
# 1991389 2019-04-07 23:57:56.941  GRAVITY  bob_44144
# 1991390 2019-04-07 23:57:56.941  GRAVITY  bob_44144
# 1991391 2019-04-07 23:57:56.941  GRAVITY  bob_44144
# 1991392 2019-04-07 23:57:56.941  GRAVITY  bob_44144
# 1991393 2019-04-07 23:57:56.943  GRAVITY  bob_44144
#
#                                                                                                              logtext  \
# 43                                                                       Started at 2019-04-02T01:29:45 (underlined)
# 44                                                          MATISSE_img_acq -- Celestial target acquisition (yellow)
# 45                                                                                                COU AG PMD = '0.0'
# 46                                                                                         COU AG EQUINOX = '2000.0'
# 47                                                                                             DET1 APOY VAL = '512'
# ...                                                                                                              ...
# 1991389                           ERROR performing command SETUP (INFO: Preset telescopes to FREE position ... (red)
# 1991390                                                   Finished in 14 seconds at 2019-04-07T23:57:56 (underlined)
# 1991391                                                                                               PRESET). (red)
# 1991392                                                                      INFO: Stop Coude auto guiding ... (red)
# 1991393  TplExecTimeStats: TPL.ID GRAVITY_dual_acq  estimated 00:15:00  real 00:00:14  diff -886 seconds (-00:14:46)
#
#          trace_id
# 43              0
# 44              0
# 45              0
# 46              0
# 47              0
# ...           ...
# 1991389       151
# 1991390       151
# 1991391       151
# 1991392       151
# 1991393       151
#
# [1991351 rows x 5 columns]

# %%
df_trace = load_all_traces("1d")
df_trace = df_trace[['@timestamp', 'system', 'procname', 'logtext', 'trace_id']]

# Filtrar por trace_id igual a 0
df_trace_filtered = df_trace[df_trace['trace_id'] == 1]

# Filtrar por el rango de fechas
#df_trace_filtered = df_trace_filtered[df_trace_filtered['@timestamp'].between('2019-04-02 00:00:00', '2019-04-07 23:59:59')]

with pd.option_context('display.max_colwidth', None):
    display(df_trace_filtered)
# Out:
#                     @timestamp   system    procname  \
# 2238   2019-04-10 00:20:35.848  MATISSE     bob_ins
# 2239   2019-04-10 00:20:35.848  MATISSE     bob_ins
# 2240   2019-04-10 00:20:36.000      AT3  logManager
# 2241   2019-04-10 00:20:36.111  MATISSE     bob_ins
# 2242   2019-04-10 00:20:36.111  MATISSE     bob_ins
# ...                        ...      ...         ...
# 305577 2019-04-10 11:03:06.817  GRAVITY     bob_ins
# 305578 2019-04-10 11:03:06.817  GRAVITY     bob_ins
# 305579 2019-04-10 11:03:06.817  GRAVITY  gvoControl
# 305580 2019-04-10 11:03:06.819  GRAVITY     bob_ins
# 305581 2019-04-10 11:03:06.821  GRAVITY     bob_ins
#
#                                                                                                                logtext  \
# 2238                                                          MATISSE_hyb_obs -- Celestial target observation (yellow)
# 2239                                                                       Started at 2019-04-10T00:20:35 (underlined)
# 2240                                                                                                 Motion execution.
# 2241                                                                                             INS FIL NAME = 'AUTO'
# 2242                                                                                         DET1 WLMAXCUT VAL = '4.8'
# ...                                                                                                                ...
# 305577                                                                                               -1 (SpringGreen4)
# 305578                             Template P2VM-WAVESC - Woll: IN, Grism: MED, DET1: 0.7, DET2: 0.3 finished. (brown)
# 305579                                                                                             SETUP command done.
# 305580                                                    Finished in 2342 seconds at 2019-04-10T11:03:06 (underlined)
# 305581  TplExecTimeStats: TPL.ID GRAVITY_gen_cal_p2vm  estimated 00:40:30  real 00:39:02  diff -88 seconds (-00:01:28)
#
#         trace_id
# 2238           1
# 2239           1
# 2240           1
# 2241           1
# 2242           1
# ...          ...
# 305577         1
# 305578         1
# 305579         1
# 305580         1
# 305581         1
#
# [22286 rows x 5 columns]

# %%
# Contar el número de trace_id igual a 0
count_trace_id_0 = (df_trace['trace_id'] == 0).sum()

print(f"Number of trace_id values equal to 0: {count_trace_id_0}")
# Out:
# Number of trace_id values equal to 0: 8261

# %% [markdown]
# # Necesitamos:
#
# 1. como identificar como empieza y termina un proceso
# 2. como identificar cuando empieza un comando y cuando termina
