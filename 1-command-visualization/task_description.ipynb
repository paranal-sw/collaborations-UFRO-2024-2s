# %% [markdown]
# # Command visualization app

# %% [markdown]
# Note: this notebook is also available in [Google Colaboratoy](https://colab.research.google.com/github/paranal-sw/collaborations-UFRO-2024-2s/blob/main/1-command-visualization/task_description.ipynb)
#
# The VLT Software has a mechanism to send command between processes. This is normally started in the instrument (PIONIER, MATISSE, GRAVITY) and in some cases like template ACQ or template OBS, the command is sent to subsystems (ISS, DL, ATx, ARAL, etc)
#
# It would be useful to have a graphical tool to understands who initiated the messages, the trip it makes through the systems, and included their parameters whenever is possible.
#
# ## Objective
# 1. Create a streamlit app to display command messages through processes.
# 1. Fill the gaps when commands send and receive are not clearly written.
# 1. Report the process to create the app and the assumtpioms made to fill the gaps.

# %% [markdown]
# Make a UML sequence diagram with the time(start and end) between process(if it fails or not), the instrument, the command(name) and the susbsystem(name),

# %% [markdown]
# ## Example app
#
# A sample streamlit app is provided to use as barebones. Please create subpages with different versions.
#
# To start the app:
#
# ```bash
# cd collaborations-UFRO-2024-2s
# source venv/bin/activate
#
# cd 1-command-visualization
# streamlit run Home_example1.py
# ```

# %%
import os 
import pandas as pd
from urllib.request import urlretrieve
REPO_URL='https://huggingface.co/datasets/Paranal/parlogs-observations/resolve/main/data'

if 'COLAB_RELEASE_TAG' in os.environ.keys():
    
    PATH='data/' # Convenient name to be Colab compatible
else:
    PATH='D:/Ufro/11 nivel/Lab modelacion 2/Trabajo_paramal/collaborations-UFRO-2024-2s/data' # Local directory to your system

def load_dataset(INSTRUMENT, RANGE):

    fname = f'{INSTRUMENT}-{RANGE}-traces.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_inst=pd.read_parquet(f'{PATH}/{fname}')

    fname = f'{INSTRUMENT}-{RANGE}-traces-SUBSYSTEMS.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_subs=pd.read_parquet(f'{PATH}/{fname}')

    fname = f'{INSTRUMENT}-{RANGE}-traces-TELESCOPES.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_tele=pd.read_parquet(f'{PATH}/{fname}')

    all_traces = [df_inst, df_subs, df_tele]

    df_all = pd.concat(all_traces)
    df_all.sort_values('@timestamp', inplace=True)
    df_all.reset_index(drop=True, inplace=True)

    return df_all

def load_trace(INSTRUMENT, RANGE, trace_id):
    df_all = load_dataset(INSTRUMENT, RANGE)
    df_all = df_all[ df_all['trace_id']==trace_id ]
    return df_all

def load_meta(INSTRUMENT, RANGE):
    fname = f'{INSTRUMENT}-{RANGE}-meta.parket'
    if not os.path.exists(f'{PATH}/{fname}'):
        urlretrieve(f'{REPO_URL}/{fname}', f'{PATH}/{fname}')
    df_meta=pd.read_parquet(f'{PATH}/{fname}')

    return df_meta

# %% [markdown]
# ## Example of command events

# %%
df_meta = load_meta("MATISSE", "1d")
df_meta
# Out:
#                      START                     END  TIMEOUT   system  \
# 0  2019-04-10 00:16:03.269 2019-04-10 00:20:35.831    False  MATISSE
# 1  2019-04-10 00:20:35.848 2019-04-10 00:42:17.085    False  MATISSE
# 2  2019-04-10 00:42:17.106 2019-04-10 01:11:09.300    False  MATISSE
# 3  2019-04-10 01:11:09.325 2019-04-10 01:22:27.609    False  MATISSE
# 4  2019-04-10 01:22:40.579 2019-04-10 01:29:34.127    False  MATISSE
# ..                     ...                     ...      ...      ...
# 65 2019-04-10 23:36:34.218 2019-04-10 23:37:22.734    False  MATISSE
# 66 2019-04-10 23:37:45.605 2019-04-10 23:40:12.335    False  MATISSE
# 67 2019-04-10 23:40:15.899 2019-04-10 23:43:40.407    False  MATISSE
# 68 2019-04-10 23:45:18.254 2019-04-10 23:51:49.993    False  MATISSE
# 69 2019-04-10 23:52:09.722 2019-04-10 23:59:09.727    False  MATISSE
#
#       procname           TPL_ID  ERROR  Aborted  SECONDS TEL
# 0      bob_ins  MATISSE_img_acq  False    False    272.0  AT
# 1      bob_ins  MATISSE_hyb_obs  False    False   1301.0  AT
# 2      bob_ins  MATISSE_hyb_obs  False    False   1732.0  AT
# 3      bob_ins  MATISSE_hyb_obs  False    False    678.0  AT
# 4      bob_ins  MATISSE_img_acq  False    False    413.0  AT
# ..         ...              ...    ...      ...      ...  ..
# 65  bob_163744  MATISSE_img_acq  False    False     48.0  AT
# 66  bob_163744  MATISSE_img_acq  False    False    146.0  AT
# 67  bob_163744  MATISSE_img_acq  False    False    204.0  AT
# 68  bob_163744  MATISSE_img_acq  False    False    391.0  AT
# 69  bob_163744  MATISSE_img_acq  False    False    420.0  AT
#
# [70 rows x 10 columns]

# %%
df_meta['Aborted'].value_counts()
# Out:
# Aborted
# False    69
# True      1
# Name: count, dtype: int64

# %%
df_meta['ERROR'].value_counts()

# %%
df_meta['TIMEOUT'].value_counts()
# Out:
# TIMEOUT
# False    70
# Name: count, dtype: int64

# %%
df_trace = load_trace("MATISSE", "1d", 0)
df_trace = df_trace[['@timestamp', 'system', 'procname', 'logtext', 'trace_id']]

# %% [markdown]
# ### Search *command*

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_trace[ df_trace['logtext'].str.contains("command") ][:50])
# Out:
#                  @timestamp   system      procname  \
# 95  2019-04-10 00:16:04.309      ISS  issifControl
# 96  2019-04-10 00:16:04.311      ISS  issifControl
# 97  2019-04-10 00:16:04.355      ISS  issifControl
# 98  2019-04-10 00:16:04.356      ISS  issifControl
# 99  2019-04-10 00:16:04.401      ISS  issifControl
# 100 2019-04-10 00:16:04.401      ISS  issifControl
# 104 2019-04-10 00:16:04.447      ISS  issifControl
# 105 2019-04-10 00:16:04.448      ISS  issifControl
# 108 2019-04-10 00:16:04.493      ISS  issifControl
# 109 2019-04-10 00:16:04.494      ISS  issifControl
# 110 2019-04-10 00:16:04.641       DL   dlifControl
# 111 2019-04-10 00:16:04.641       DL   dlifControl
# 152 2019-04-10 00:16:04.932  MATISSE    mtoControl
# 155 2019-04-10 00:16:04.936  MATISSE    mtoControl
# 159 2019-04-10 00:16:05.071  MATISSE    mtoControl
# 161 2019-04-10 00:16:05.879  MATISSE    mtoControl
# 163 2019-04-10 00:16:05.880  MATISSE    mtoControl
# 166 2019-04-10 00:16:06.270       DL   dlifControl
# 167 2019-04-10 00:16:06.270       DL   dlifControl
# 171 2019-04-10 00:16:07.484  MATISSE    mtoControl
# 173 2019-04-10 00:16:07.485  MATISSE    mtoControl
# 175 2019-04-10 00:16:07.624       DL   dlifControl
# 176 2019-04-10 00:16:07.624       DL   dlifControl
# 178 2019-04-10 00:16:08.955       DL   dlifControl
# 179 2019-04-10 00:16:08.956       DL   dlifControl
# 187 2019-04-10 00:16:09.690  MATISSE    mtoControl
# 189 2019-04-10 00:16:09.699  MATISSE       bob_ins
# 190 2019-04-10 00:16:09.700      ISS  issifControl
# 191 2019-04-10 00:16:09.701  MATISSE       bob_ins
# 192 2019-04-10 00:16:09.765      ISS  issifControl
# 197 2019-04-10 00:16:10.217       DL   dlifControl
# 198 2019-04-10 00:16:10.217       DL   dlifControl
# 201 2019-04-10 00:16:10.703  MATISSE       bob_ins
# 203 2019-04-10 00:16:10.705  MATISSE       bob_ins
# 204 2019-04-10 00:16:10.707  MATISSE       bob_ins
# 205 2019-04-10 00:16:10.707      ISS  issifControl
# 206 2019-04-10 00:16:10.708      ISS  issifControl
# 207 2019-04-10 00:16:10.710  MATISSE       bob_ins
# 208 2019-04-10 00:16:10.712  MATISSE       bob_ins
# 209 2019-04-10 00:16:10.714  MATISSE       bob_ins
# 210 2019-04-10 00:16:10.714      ISS  issifControl
# 211 2019-04-10 00:16:10.715      ISS  issifControl
# 212 2019-04-10 00:16:10.717  MATISSE       bob_ins
# 214 2019-04-10 00:16:10.723  MATISSE       bob_ins
# 215 2019-04-10 00:16:10.725  MATISSE       bob_ins
# 216 2019-04-10 00:16:10.725      ISS  issifControl
# 217 2019-04-10 00:16:10.727     ARAL    aroControl
# 220 2019-04-10 00:16:11.416      ISS  issifControl
# 221 2019-04-10 00:16:11.554       DL   dlifControl
# 222 2019-04-10 00:16:11.555       DL   dlifControl
#
#                                                                                                                                                                    logtext  \
# 95                                                                                                                              CDP   : Received command: GETCONF, Buffer:
# 96   CDP   : Succesfully completed command: GETCONF, Buffer: IRIS,#012SINGLE_STS,#0121,AT1,A0,DL6,1,compressed,147.596,12.545,8.323,#0122,AT2,B2,DL5,3,compressed,163.345,
# 97                                                                                                                             CDP   : Received command: GETWCS, Buffer: 2
# 98                                                                                 CDP   : Succesfully completed command: GETWCS, Buffer: 109.144148,-27.880972,270.111594
# 99                                                                                                                             CDP   : Received command: GETWCS, Buffer: 1
# 100                                                                                CDP   : Succesfully completed command: GETWCS, Buffer: 109.144148,-27.880972,270.111594
# 104                                                                                                                            CDP   : Received command: GETWCS, Buffer: 3
# 105                                                                                CDP   : Succesfully completed command: GETWCS, Buffer: 109.144148,-27.880972,270.111594
# 108                                                                                                                            CDP   : Received command: GETWCS, Buffer: 4
# 109                                                                                CDP   : Succesfully completed command: GETWCS, Buffer: 109.144149,-27.881805,270.111594
# 110                                                                                                                         TIF   : Received command: GETDELD, Buffer: dl1
# 111                                TIF   : Succesfully completed command: GETDELD, Buffer: dl1,AT3,D0,0.010000,-48.012000,4.539700,115.105000,5,8.295000,14.308000,DEFAULT
# 152                                                                                                                                            Executing SETUP command ...
# 155                                                                                                                                                    SETUP command done.
# 159                                                                                                                                            Executing SETUP command ...
# 161                                                                                                                                                    SETUP command done.
# 163                                                                                                                                            Executing SETUP command ...
# 166                              TIF   : Succesfully completed command: GETDELD, Buffer: dl2,AT4,C1,-16.002000,-64.011000,4.539700,146.875000,7,9.045000,20.658000,DEFAULT
# 167                                                                                                                         TIF   : Received command: GETDELD, Buffer: dl2
# 171                                                                                                                                                    SETUP command done.
# 173                                                                                                                                            Executing SETUP command ...
# 175                               TIF   : Succesfully completed command: GETDELD, Buffer: dl3,UT3,U3,64.001300,47.972500,13.053400,198.681000,5,8.295000,18.608000,DEFAULT
# 176                                                                                                                         TIF   : Received command: GETDELD, Buffer: dl3
# 178                                                                                                                         TIF   : Received command: GETDELD, Buffer: dl4
# 179                               TIF   : Succesfully completed command: GETDELD, Buffer: dl4,UT4,U4,112.000000,8.000000,13.044000,208.927000,7,9.045000,25.918000,DEFAULT
# 187                                                                                                                                                    SETUP command done.
# 189                                                                                   Send command CHKMOON 120800.813,-444910.060,8.1 to process issifControl env. wvgvlti
# 190                                                                                                  CDP   : Received command: CHKMOON, Buffer: 120800.813,-444910.060,8.1
# 191                                                                                                 Waiting (timeout 40000) for pending replies to command CHKMOON id cmd5
# 192                                                                                                             CDP   : Succesfully completed command: CHKMOON, Buffer: OK
# 197                             TIF   : Succesfully completed command: GETDELD, Buffer: dl5,AT2,B2,-23.991000,-72.011000,4.539700,163.345000,3,11.795000,16.515000,DEFAULT
# 198                                                                                                                         TIF   : Received command: GETDELD, Buffer: dl5
# 201                                                                                                                         Last reply to command CHKMOON id cmd5 received
# 203                                                                                                              Send command GETIAS  to process issifControl env. wvgvlti
# 204                                                                                                  Waiting (timeout 40000) for pending replies to command GETIAS id cmd5
# 205                                                                                                                              CDP   : Received command: GETIAS, Buffer:
# 206                                                                                                            CDP   : Succesfully completed command: GETIAS, Buffer: IRIS
# 207                                                                                                                          Last reply to command GETIAS id cmd5 received
# 208                                                                                                              Send command GETIAS  to process issifControl env. wvgvlti
# 209                                                                                                  Waiting (timeout 40000) for pending replies to command GETIAS id cmd5
# 210                                                                                                                              CDP   : Received command: GETIAS, Buffer:
# 211                                                                                                            CDP   : Succesfully completed command: GETIAS, Buffer: IRIS
# 212                                                                                                                          Last reply to command GETIAS id cmd5 received
# 214                                                                                                             Send command STOPLAG  to process issifControl env. wvgvlti
# 215                                                                                                 Waiting (timeout 35000) for pending replies to command STOPLAG id cmd5
# 216                                                                                                                             CDP   : Received command: STOPLAG, Buffer:
# 217                                                                                                                     Send command 'STOPLAG' '' to sub-system 'IRIS' ...
# 220                                                                                                             CDP   : Succesfully completed command: STOPLAG, Buffer: OK
# 221                                                                                                                         TIF   : Received command: GETDELD, Buffer: dl6
# 222                              TIF   : Succesfully completed command: GETDELD, Buffer: dl6,AT1,A0,-32.001000,-48.013000,4.539700,147.596000,1,12.545000,8.323000,DEFAULT
#
#      trace_id
# 95          0
# 96          0
# 97          0
# 98          0
# 99          0
# 100         0
# 104         0
# 105         0
# 108         0
# 109         0
# 110         0
# 111         0
# 152         0
# 155         0
# 159         0
# 161         0
# 163         0
# 166         0
# 167         0
# 171         0
# 173         0
# 175         0
# 176         0
# 178         0
# 179         0
# 187         0
# 189         0
# 190         0
# 191         0
# 192         0
# 197         0
# 198         0
# 201         0
# 203         0
# 204         0
# 205         0
# 206         0
# 207         0
# 208         0
# 209         0
# 210         0
# 211         0
# 212         0
# 214         0
# 215         0
# 216         0
# 217         0
# 220         0
# 221         0
# 222         0

# %% [markdown]
# ### List of commands
#
# This method must be double checked

# %%
cmd = df_trace[ df_trace['logtext'].str.contains("command")]['logtext']

# Please replace this with an elegant regexp!
cmd = cmd.apply(lambda x: x.replace(":", " "))
cmd = cmd.apply(lambda x: x.replace(",", " "))
cmd = cmd.apply(lambda x: x.replace("'", " "))
cmd = cmd.apply(lambda x: x.replace("  ", " "))

cmdlist = []
for x in cmd:
    splitted = x.split()
    # print(splitted)
    if "command" in splitted:
        idx = splitted.index("command")
        command = splitted[idx+1]
        if command not in ["...", "done.", "to"]:
            cmdlist.append(command)
set(cmdlist)
# Out:
# {'CHKMOON',
#  'CLRSTP',
#  'GETCONF',
#  'GETDELD',
#  'GETIAS',
#  'GETWCS',
#  'PRABS',
#  'PRCHK',
#  'PRESET',
#  'PRSNAME',
#  'PRTOGS',
#  'SETBEAM',
#  'SETPOF',
#  'SETREF',
#  'SETTADC',
#  'SETUP',
#  'STOPAG',
#  'STOPCAG',
#  'STOPCHP',
#  'STOPLAG',
#  'STRTLAG'}

# %% [markdown]
# ### Search *SETUP*

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_trace[ df_trace['logtext'].str.contains("SETUP") ][:50])
# Out:
#                  @timestamp   system       procname  \
# 151 2019-04-10 00:16:04.931  MATISSE        bob_ins
# 152 2019-04-10 00:16:04.932  MATISSE     mtoControl
# 153 2019-04-10 00:16:04.933  MATISSE     mtoControl
# 154 2019-04-10 00:16:04.933  MATISSE     mtoControl
# 155 2019-04-10 00:16:04.936  MATISSE     mtoControl
# 159 2019-04-10 00:16:05.071  MATISSE     mtoControl
# 160 2019-04-10 00:16:05.071  MATISSE        bob_ins
# 161 2019-04-10 00:16:05.879  MATISSE     mtoControl
# 163 2019-04-10 00:16:05.880  MATISSE     mtoControl
# 164 2019-04-10 00:16:05.880  MATISSE        bob_ins
# 171 2019-04-10 00:16:07.484  MATISSE     mtoControl
# 173 2019-04-10 00:16:07.485  MATISSE     mtoControl
# 174 2019-04-10 00:16:07.485  MATISSE        bob_ins
# 187 2019-04-10 00:16:09.690  MATISSE     mtoControl
# 254 2019-04-10 00:16:15.778  MATISSE        bob_ins
# 255 2019-04-10 00:16:15.779  MATISSE     mtoControl
# 256 2019-04-10 00:16:15.780  MATISSE     mtoControl
# 257 2019-04-10 00:16:15.780  MATISSE     mtoControl
# 258 2019-04-10 00:16:15.785  MATISSE     mtoControl
# 352 2019-04-10 00:16:17.873  MATISSE        bob_ins
# 355 2019-04-10 00:16:17.876      ISS  issprsControl
# 357 2019-04-10 00:16:17.876      ISS   issifControl
# 358 2019-04-10 00:16:17.876      ISS  issprsControl
# 364 2019-04-10 00:16:17.889  MATISSE        bob_ins
# 370 2019-04-10 00:16:17.889  MATISSE     mtoControl
# 376 2019-04-10 00:16:17.895  MATISSE     mtoControl
# 377 2019-04-10 00:16:17.895  MATISSE     mtoControl
# 415 2019-04-10 00:16:18.609      AT1    atifControl
# 416 2019-04-10 00:16:18.609      AT1     prsControl
# 417 2019-04-10 00:16:18.610      AT2    atifControl
# 418 2019-04-10 00:16:18.611      AT2     prsControl
# 419 2019-04-10 00:16:18.613      AT3    atifControl
# 420 2019-04-10 00:16:18.614      AT3     prsControl
# 421 2019-04-10 00:16:18.614      AT4    atifControl
# 422 2019-04-10 00:16:18.615      AT4     prsControl
# 423 2019-04-10 00:16:18.616       DL    dlifControl
# 424 2019-04-10 00:16:18.617       DL   dlprsControl
# 425 2019-04-10 00:16:18.618     ARAL     aroControl
# 426 2019-04-10 00:16:18.623     ARAL     aroControl
# 427 2019-04-10 00:16:18.623     ARAL  iriswsControl
# 441 2019-04-10 00:16:18.624      AT1  atagwsControl
# 444 2019-04-10 00:16:18.624      AT1    pscsControl
# 445 2019-04-10 00:16:18.624      AT1    pscsControl
# 448 2019-04-10 00:16:18.625     ARAL  iriswsControl
# 453 2019-04-10 00:16:18.626      AT2    pscsControl
# 454 2019-04-10 00:16:18.626      AT2    pscsControl
# 455 2019-04-10 00:16:18.626      AT2  atagwsControl
# 469 2019-04-10 00:16:18.628     ARAL     aroControl
# 486 2019-04-10 00:16:18.633      AT3    pscsControl
# 489 2019-04-10 00:16:18.633      AT3  atagwsControl
#
#                                                                                                                                                                             logtext  \
# 151                                                                                                           SETUP -noExposure -function DET1.START.VAL 1  DET2.START.VAL 1 (blue)
# 152                                                                                                                                                     Executing SETUP command ...
# 153                                                                                                                                                      Forward(b) SETUP to NGCIR2
# 154                                                                                                                                                      Forward(b) SETUP to NGCIR1
# 155                                                                                                                                                             SETUP command done.
# 159                                                                                                                                                     Executing SETUP command ...
# 160                                                                                                                                SETUP -expoId 0 -function INS.MODE HYBRID (blue)
# 161                                                                                                                                                             SETUP command done.
# 163                                                                                                                                                     Executing SETUP command ...
# 164                                                                   SETUP -expoId 146 -function INS.MODE HYBRID INS.BSL1.ST T  INS.BSL2.ST T  INS.BSL3.ST T  INS.BSL4.ST T (blue)
# 171                                                                                                                                                             SETUP command done.
# 173                                                                                                                                                     Executing SETUP command ...
# 174                                                                   SETUP -expoId 146 -function INS.MODE HYBRID INS.BSN1.ST T  INS.BSN2.ST T  INS.BSN3.ST T  INS.BSN4.ST T (blue)
# 187                                                                                                                                                             SETUP command done.
# 254                                           SETUP -expoId 146 -function DET1.START.VAL 0  DET1.TPLID.VAL MATISSE_FRINGES  DET2.START.VAL 0  DET2.TPLID.VAL MATISSE_FRINGES (blue)
# 255                                                                                                                                                     Executing SETUP command ...
# 256                                                                                                                                                      Forward(b) SETUP to NGCIR1
# 257                                                                                                                                                      Forward(b) SETUP to NGCIR2
# 258                                                                                                                                                             SETUP command done.
# 352                     Send command SETUP ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.813 TEL.TARG.ADDVELALPHA 0.0 TEL.TARG.PMA -0.012588 TEL.GS1.DELTA 0. TEL.CHOP.THROW 4.5
# 355                                                                                     evhERR_CMD_NOT_CHECKED : Command SETUP not checked sent by proc issifControl on env wvgvlti
# 357                                   CDP   : Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.813 TEL.TARG.ADDVELALPHA 0.0 TEL.TARG.PMA -0.012588
# 358                                                                          CONTROL: Received command: SETUP, Buffer: 0,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.813 TEL.TA
# 364           SETUP -expoId 146 -file MATISSE_img_acq.ref  -function INS.MODE HYBRID  INS.BCTP1.ENC 29992 INS.BCTP2.ENC 29752 INS.BCTP3.ENC 40044 INS.BCTP4.ENC 32197 INS.BCTT1.ENC
# 370                                                                                                                                                     Executing SETUP command ...
# 376                                                                                                                                                      Forward(b) SETUP to NGCIR1
# 377                                                                                                                                                      Forward(b) SETUP to NGCIR2
# 415                                   TIF   : Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TARG.DELTA -444910.064 TEL.TARG.EPOCH 2000.
# 416                                                                           PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
# 417                                   TIF   : Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TARG.DELTA -444910.064 TEL.TARG.EPOCH 2000.
# 418                                                                           PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
# 419                                   TIF   : Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TARG.DELTA -444910.064 TEL.TARG.EPOCH 2000.
# 420                                                                           PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
# 421                                   TIF   : Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TARG.DELTA -444910.064 TEL.TARG.EPOCH 2000.
# 422                                                                           PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
# 423                                   TIF   : Received command: SETUP, Buffer: ,,DEL.TARG.TYPE OBJ_COORD TEL.TARG.ALPHA 120800.813 TEL.TARG.DELTA -444910.060 TEL.TARG.EPOCH 2000.0
# 424            PRESET: Received command: SETUP, Buffer: ,,DEL.TARG.TYPE OBJ_COORD TEL.TARG.ALPHA 120800.813 TEL.TARG.DELTA -444910.060 TEL.TARG.EPOCH 2000.000 TEL.TARG.EPOCHSYS...
# 425                                                                                                                                                     Executing SETUP command ...
# 426                                                                                                                                                        Forward(b) SETUP to IRIS
# 427                                                                                                                                                     Executing SETUP command ...
# 441                                                                         eccsERR_BUF_TOO_BIG : Buffer too big. Size: 703, Max allowed size: 176, Buffer: atagwsCON_SETUP::Set...
# 444                                                                                                                                                               STS: SETUP buffer
# 445  T" TEL.ROT.ALTAZTRACK "F" COU.AG.TYPE "ADAPT_OPT" COU.AG.START "F" COU.AG.GSSOURCE "SETUPFILE" COU.AG.OPTIMIZE "F" COU.AG.ALPHA 120800.790 COU.AG.DELTA -444910.136 COU.GS.MAG
# 448                                                                                                                                                             SETUP command done.
# 453                                                                                                                                                               STS: SETUP buffer
# 454  T" TEL.ROT.ALTAZTRACK "F" COU.AG.TYPE "ADAPT_OPT" COU.AG.START "F" COU.AG.GSSOURCE "SETUPFILE" COU.AG.OPTIMIZE "F" COU.AG.ALPHA 120800.790 COU.AG.DELTA -444910.136 COU.GS.MAG
# 455                                                                         eccsERR_BUF_TOO_BIG : Buffer too big. Size: 703, Max allowed size: 176, Buffer: atagwsCON_SETUP::Set...
# 469                                                                                                                                                             SETUP command done.
# 486                                                                                                                                                               STS: SETUP buffer
# 489                                                                         eccsERR_BUF_TOO_BIG : Buffer too big. Size: 703, Max allowed size: 176, Buffer: atagwsCON_SETUP::Set...
#
#      trace_id
# 151         0
# 152         0
# 153         0
# 154         0
# 155         0
# 159         0
# 160         0
# 161         0
# 163         0
# 164         0
# 171         0
# 173         0
# 174         0
# 187         0
# 254         0
# 255         0
# 256         0
# 257         0
# 258         0
# 352         0
# 355         0
# 357         0
# 358         0
# 364         0
# 370         0
# 376         0
# 377         0
# 415         0
# 416         0
# 417         0
# 418         0
# 419         0
# 420         0
# 421         0
# 422         0
# 423         0
# 424         0
# 425         0
# 426         0
# 427         0
# 441         0
# 444         0
# 445         0
# 448         0
# 453         0
# 454         0
# 455         0
# 469         0
# 486         0
# 489         0

# %% [markdown]
# ### Search *PRESET*

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_trace[ df_trace['logtext'].str.contains("PRESET") ][:59])
# Out:
#                   @timestamp   system      procname  \
# 65   2019-04-10 00:16:03.534  MATISSE       bob_ins
# 266  2019-04-10 00:16:15.793      AT1    prsControl
# 268  2019-04-10 00:16:15.794      AT2    prsControl
# 269  2019-04-10 00:16:15.795      AT3    prsControl
# 272  2019-04-10 00:16:15.796      AT4    prsControl
# 275  2019-04-10 00:16:15.797       DL  dlprsControl
# 276  2019-04-10 00:16:15.801       DL  dlprsControl
# 279  2019-04-10 00:16:15.843      AT1    prsControl
# 281  2019-04-10 00:16:15.859      AT3    prsControl
# 283  2019-04-10 00:16:15.873      AT2    prsControl
# 286  2019-04-10 00:16:15.880      AT4    prsControl
# 361  2019-04-10 00:16:17.884      ISS  issprsAction
# 414  2019-04-10 00:16:18.568      ISS  issprsAction
# 416  2019-04-10 00:16:18.609      AT1    prsControl
# 418  2019-04-10 00:16:18.611      AT2    prsControl
# 420  2019-04-10 00:16:18.614      AT3    prsControl
# 422  2019-04-10 00:16:18.615      AT4    prsControl
# 424  2019-04-10 00:16:18.617       DL  dlprsControl
# 434  2019-04-10 00:16:18.624      AT1   pscsControl
# 462  2019-04-10 00:16:18.627      AT2   pscsControl
# 492  2019-04-10 00:16:18.633      AT3   pscsControl
# 501  2019-04-10 00:16:18.635      AT4   pscsControl
# 724  2019-04-10 00:16:20.117      AT2  nmmgrControl
# 738  2019-04-10 00:16:20.118      AT1  nmmgrControl
# 768  2019-04-10 00:16:20.123      AT3  nmmgrControl
# 779  2019-04-10 00:16:20.126      AT4  nmmgrControl
# 856  2019-04-10 00:16:23.758       DL   dlprsAction
# 978  2019-04-10 00:17:12.993       DL  dlprsControl
# 1592 2019-04-10 00:19:22.234      AT1    prsControl
# 1613 2019-04-10 00:19:26.413      AT3    prsControl
# 1653 2019-04-10 00:19:34.670      AT2    prsControl
# 1669 2019-04-10 00:19:39.469      AT4    prsControl
#
#                                                                                                                                                                               logtext  \
# 65                                                                                                                                                                SEQ PRESET ST = 'T'
# 266                                                                                                                                         PRESET: Received command: CLRSTP, Buffer:
# 268                                                                                                                                         PRESET: Received command: CLRSTP, Buffer:
# 269                                                                                                                                         PRESET: Received command: CLRSTP, Buffer:
# 272                                                                                                                                         PRESET: Received command: CLRSTP, Buffer:
# 275                                                                                                                                         PRESET: Received command: CLRSTP, Buffer:
# 276                                                                                                                             PRESET: Command CLRSTP (NoMove) succesfully completed
# 279                                                                                                                            PRESET: Command STOPTRK (NoMove) succesfully completed
# 281                                                                                                                            PRESET: Command STOPTRK (NoMove) succesfully completed
# 283                                                                                                                            PRESET: Command STOPTRK (NoMove) succesfully completed
# 286                                                                                                                            PRESET: Command STOPTRK (NoMove) succesfully completed
# 361                                                                            ACTION: Received command: PRESET, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.813 TEL.TAR
# 414                                                                                                                           ACTION: Send command to issmswControl : PRESET, Buffer:
# 416                                                                             PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
# 418                                                                             PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
# 420                                                                             PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
# 422                                                                             PRESET: Received command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
# 424              PRESET: Received command: SETUP, Buffer: ,,DEL.TARG.TYPE OBJ_COORD TEL.TARG.ALPHA 120800.813 TEL.TARG.DELTA -444910.060 TEL.TARG.EPOCH 2000.000 TEL.TARG.EPOCHSYS...
# 434   8.1 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" T
# 462   8.1 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" T
# 492   8.1 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" ISS.PRI.PS.ALPHA 120800.812 ISS.PRI.PS.DELTA -444910.064 ISS.PRI.PS.COOR
# 501   8.1 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" T
# 724   8.1 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" T
# 738   8.1 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" T
# 768   8.1 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" ISS.PRI.PS.ALPHA 120800.812 ISS.PRI.PS.DELTA -444910.064 ISS.PRI.PS.COOR
# 779   8.1 COU.GS.WAVELEN 600.00000 COU.AG.OBJCNT "F" COU.AO.START "T" ISS.PRI.PRESET.TYPE "MEASUREMENT_SWAP" TEL.AG.TYPE "FIELD_STAB" TEL.AG.START "F" TEL.AG.GUIDESTAR "CATALOGUE" T
# 856                                                                                                                                        PRESET: All tracking VCMs within tolerance
# 978                                                               PRESET: Succesfully completed. Command: SETUP, Buffer: ,,DEL.TARG.TYPE OBJ_COORD TEL.TARG.ALPHA 120800.813 TEL.TARG
# 1592                                                              PRESET: Succesfully completed. Command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
# 1613                                                              PRESET: Succesfully completed. Command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
# 1653                                                              PRESET: Succesfully completed. Command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
# 1669                                                              PRESET: Succesfully completed. Command: SETUP, Buffer: ,,TEL.TARG.TYPE COORDINATE TEL.TARG.ALPHA 120800.343 TEL.TAR
#
#       trace_id
# 65           0
# 266          0
# 268          0
# 269          0
# 272          0
# 275          0
# 276          0
# 279          0
# 281          0
# 283          0
# 286          0
# 361          0
# 414          0
# 416          0
# 418          0
# 420          0
# 422          0
# 424          0
# 434          0
# 462          0
# 492          0
# 501          0
# 724          0
# 738          0
# 768          0
# 779          0
# 856          0
# 978          0
# 1592         0
# 1613         0
# 1653         0
# 1669         0

# %%
import pandas as pd
# the location of the files data
file_path = 'D:/Ufro/11 nivel/Lab modelacion 2/Trabajo_paramal/collaborations-UFRO-2024-2s/data/PIONIER-1w-meta.parket'
# read the dataframe from the parquet file
df = pd.read_parquet(file_path)
df
# Out:
#                       START                     END  TIMEOUT   system  \
# 0   2019-04-01 22:29:07.746 2019-04-01 22:29:10.519    False  PIONIER
# 1   2019-04-02 07:40:48.591 2019-04-02 07:41:21.459    False  PIONIER
# 2   2019-04-02 07:41:21.488 2019-04-02 07:42:52.294    False  PIONIER
# 3   2019-04-02 07:42:52.314 2019-04-02 07:43:24.984    False  PIONIER
# 4   2019-04-02 09:21:52.714 2019-04-02 09:22:25.281    False  PIONIER
# ..                      ...                     ...      ...      ...
# 389 2019-04-07 20:37:40.154 2019-04-07 20:38:04.954    False  PIONIER
# 390 2019-04-07 20:38:04.980 2019-04-07 20:39:04.254    False  PIONIER
# 391 2019-04-07 20:39:04.272 2019-04-07 20:39:29.141    False  PIONIER
# 392 2019-04-07 20:39:29.165 2019-04-07 20:40:03.846    False  PIONIER
# 393 2019-04-07 22:32:16.801 2019-04-07 22:32:21.379    False  PIONIER
#
#       procname                   TPL_ID  ERROR  Aborted  SECONDS TEL
# 0      bob_ins    PIONIER_gen_tec_setup  False    False      2.0  AT
# 1    bob_25299    PIONIER_gen_tec_setup  False    False     32.0  AT
# 2    bob_25299  PIONIER_gen_tec_niobate  False    False     90.0  AT
# 3    bob_25299    PIONIER_gen_tec_setup  False    False     32.0  AT
# 4      bob_ins    PIONIER_gen_tec_setup  False    False     32.0  AT
# ..         ...                      ...    ...      ...      ...  ..
# 389    bob_ins    PIONIER_gen_tec_setup  False    False     24.0  AT
# 390    bob_ins  PIONIER_gen_tec_niobate  False    False     59.0  AT
# 391    bob_ins    PIONIER_gen_tec_setup  False    False     24.0  AT
# 392    bob_ins  PIONIER_gen_tec_standby  False    False     34.0  AT
# 393    bob_ins    PIONIER_gen_tec_setup  False    False      4.0  AT
#
# [394 rows x 10 columns]

# %%
df_meta = load_meta("PIONIER", "1w")
df_meta
# Out:
#                       START                     END  TIMEOUT   system  \
# 0   2019-04-01 22:29:07.746 2019-04-01 22:29:10.519    False  PIONIER
# 1   2019-04-02 07:40:48.591 2019-04-02 07:41:21.459    False  PIONIER
# 2   2019-04-02 07:41:21.488 2019-04-02 07:42:52.294    False  PIONIER
# 3   2019-04-02 07:42:52.314 2019-04-02 07:43:24.984    False  PIONIER
# 4   2019-04-02 09:21:52.714 2019-04-02 09:22:25.281    False  PIONIER
# ..                      ...                     ...      ...      ...
# 389 2019-04-07 20:37:40.154 2019-04-07 20:38:04.954    False  PIONIER
# 390 2019-04-07 20:38:04.980 2019-04-07 20:39:04.254    False  PIONIER
# 391 2019-04-07 20:39:04.272 2019-04-07 20:39:29.141    False  PIONIER
# 392 2019-04-07 20:39:29.165 2019-04-07 20:40:03.846    False  PIONIER
# 393 2019-04-07 22:32:16.801 2019-04-07 22:32:21.379    False  PIONIER
#
#       procname                   TPL_ID  ERROR  Aborted  SECONDS TEL
# 0      bob_ins    PIONIER_gen_tec_setup  False    False      2.0  AT
# 1    bob_25299    PIONIER_gen_tec_setup  False    False     32.0  AT
# 2    bob_25299  PIONIER_gen_tec_niobate  False    False     90.0  AT
# 3    bob_25299    PIONIER_gen_tec_setup  False    False     32.0  AT
# 4      bob_ins    PIONIER_gen_tec_setup  False    False     32.0  AT
# ..         ...                      ...    ...      ...      ...  ..
# 389    bob_ins    PIONIER_gen_tec_setup  False    False     24.0  AT
# 390    bob_ins  PIONIER_gen_tec_niobate  False    False     59.0  AT
# 391    bob_ins    PIONIER_gen_tec_setup  False    False     24.0  AT
# 392    bob_ins  PIONIER_gen_tec_standby  False    False     34.0  AT
# 393    bob_ins    PIONIER_gen_tec_setup  False    False      4.0  AT
#
# [394 rows x 10 columns]
