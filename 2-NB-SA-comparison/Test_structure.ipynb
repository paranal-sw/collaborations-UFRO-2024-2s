# %% [markdown]
# Este Notebook es para realizar pruebas de la estructura que tengo en mente.

# %%
from Structure import Core

Base = Core(time_it=True)  # El objeto por defecto obtiene el dataframe de load_meta('MATISSE','1d')
                           # el argumento "time_it" es solo para activar un medidor de tiempo de los métodos.
# Out:
# Loading Metadata for:
# INSTRUMENT: MATISSE
# RANGE: 1d
#
# Done.

# %%
Base.meta_data.head()  # el habitual "df_meta" queda guardado en el atributo meta_data
# Out:
#                     START                     END  TIMEOUT   system procname  \
# 0 2019-04-10 00:16:03.269 2019-04-10 00:20:35.831    False  MATISSE  bob_ins
# 1 2019-04-10 00:20:35.848 2019-04-10 00:42:17.085    False  MATISSE  bob_ins
# 2 2019-04-10 00:42:17.106 2019-04-10 01:11:09.300    False  MATISSE  bob_ins
# 3 2019-04-10 01:11:09.325 2019-04-10 01:22:27.609    False  MATISSE  bob_ins
# 4 2019-04-10 01:22:40.579 2019-04-10 01:29:34.127    False  MATISSE  bob_ins
#
#             TPL_ID  ERROR  Aborted  SECONDS TEL
# 0  MATISSE_img_acq  False    False    272.0  AT
# 1  MATISSE_hyb_obs  False    False   1301.0  AT
# 2  MATISSE_hyb_obs  False    False   1732.0  AT
# 3  MATISSE_hyb_obs  False    False    678.0  AT
# 4  MATISSE_img_acq  False    False    413.0  AT

# %%
Base.meta_data[Base.meta_data['ERROR'] == True]  # Buscar un error
# Out:
#                      START                     END  TIMEOUT   system procname  \
# 9  2019-04-10 02:29:03.290 2019-04-10 02:34:37.571    False  MATISSE  bob_ins
# 51 2019-04-10 20:57:47.358 2019-04-10 21:05:44.126    False  MATISSE  bob_ins
# 52 2019-04-10 21:05:44.126 2019-04-10 21:09:08.833    False  MATISSE  bob_ins
#
#              TPL_ID  ERROR  Aborted  SECONDS TEL
# 9   MATISSE_img_acq   True    False    334.0  AT
# 51      errseverity   True    False    476.0  AT
# 52      errseverity   True    False    204.0  AT

# %%
Base.load_trace(index=9)  # el método "load_trace" cargará la traza asociada al seleccionado índice
# Out:
# Loading Trace for ID: 9
# Done.
# Execution time:  0.46764149999944493  Seconds

# %%
Base.meta_tokenization()  # Este método tokenizará cada traza en meta_data y lo cargará en una columna llamada "Trace_tokens"
# Out:
# Loading Trace for ID: 0
# Done.
# Loading Trace for ID: 1
# Done.
# Loading Trace for ID: 2
# Done.
# Loading Trace for ID: 3
# Done.
# Loading Trace for ID: 4
# Done.
# Loading Trace for ID: 5
# Done.
# Loading Trace for ID: 6
# Done.
# Loading Trace for ID: 7
# Done.
# Loading Trace for ID: 8
# Done.
# Loading Trace for ID: 9
# Done.
# Loading Trace for ID: 10
# Done.
# Loading Trace for ID: 11
# Done.
# Loading Trace for ID: 12
# Done.
# Loading Trace for ID: 13
# Done.
# Loading Trace for ID: 14
# Done.
# Loading Trace for ID: 15
# Done.
# Loading Trace for ID: 16
# Done.
# Loading Trace for ID: 17
# Done.
# Loading Trace for ID: 18
# Done.
# Loading Trace for ID: 19
# Done.
# Loading Trace for ID: 20
# Done.
# Loading Trace for ID: 21
# Done.
# Loading Trace for ID: 22
# Done.
# Loading Trace for ID: 23
# Done.
# Loading Trace for ID: 24
# Done.
# Loading Trace for ID: 25
# Done.
# Loading Trace for ID: 26
# Done.
# Loading Trace for ID: 27
# Done.
# Loading Trace for ID: 28
# Done.
# Loading Trace for ID: 29
# Done.
# Loading Trace for ID: 30
# Done.
# Loading Trace for ID: 31
# Done.
# Loading Trace for ID: 32
# Done.
# Loading Trace for ID: 33
# Done.
# Loading Trace for ID: 34
# Done.
# Loading Trace for ID: 35
# Done.
# Loading Trace for ID: 36
# Done.
# Loading Trace for ID: 37
# Done.
# Loading Trace for ID: 38
# Done.
# Loading Trace for ID: 39
# Done.
# Loading Trace for ID: 40
# Done.
# Loading Trace for ID: 41
# Done.
# Loading Trace for ID: 42
# Done.
# Loading Trace for ID: 43
# Done.
# Loading Trace for ID: 44
# Done.
# Loading Trace for ID: 45
# Done.
# Loading Trace for ID: 46
# Done.
# Loading Trace for ID: 47
# Done.
# Loading Trace for ID: 48
# Done.
# Loading Trace for ID: 49
# Done.
# Loading Trace for ID: 50
# Done.
# Loading Trace for ID: 51
# Done.
# Loading Trace for ID: 52
# Done.
# Loading Trace for ID: 53
# Done.
# Loading Trace for ID: 54
# Done.
# Loading Trace for ID: 55
# Done.
# Loading Trace for ID: 56
# Done.
# Loading Trace for ID: 57
# Done.
# Loading Trace for ID: 58
# Done.
# Loading Trace for ID: 59
# Done.
# Loading Trace for ID: 60
# Done.
# Loading Trace for ID: 61
# Done.
# Loading Trace for ID: 62
# Done.
# Loading Trace for ID: 63
# Done.
# Loading Trace for ID: 64
# Done.
# Loading Trace for ID: 65
# Done.
# Loading Trace for ID: 66
# Done.
# Loading Trace for ID: 67
# Done.
# Loading Trace for ID: 68
# Done.
# Loading Trace for ID: 69
# Done.
# Execution time:  26.14322369999718  Seconds

# %%
Base.trace_data
# Out:
#                    @timestamp   system hostname loghost logtype envname  \
# 60067 2019-04-10 02:29:03.290  MATISSE      wmt     wmt     LOG     wmt
# 60068 2019-04-10 02:29:03.290  MATISSE      wmt     wmt     LOG     wmt
# 60069 2019-04-10 02:29:03.554  MATISSE      wmt     wmt     LOG     wmt
# 60070 2019-04-10 02:29:03.554  MATISSE      wmt     wmt     LOG     wmt
# 60071 2019-04-10 02:29:03.554  MATISSE      wmt     wmt     LOG     wmt
# ...                       ...      ...      ...     ...     ...     ...
# 62950 2019-04-10 02:34:37.567  MATISSE      wmt     wmt     LOG     wmt
# 62951 2019-04-10 02:34:37.567  MATISSE      wmt     wmt     LOG     wmt
# 62952 2019-04-10 02:34:37.568  MATISSE      wmt     wmt     LOG     wmt
# 62953 2019-04-10 02:34:37.570  MATISSE      wmt     wmt     LOG     wmt
# 62954 2019-04-10 02:34:37.571  MATISSE      wmt     wmt     LOG     wmt
#
#          procname  procid module keywname keywvalue keywmask  \
# 60067     bob_ins   155.0    seq
# 60068     bob_ins   155.0    seq
# 60069     bob_ins   155.0    seq
# 60070     bob_ins   155.0    seq
# 60071     bob_ins   155.0    seq
# ...           ...     ...    ...      ...       ...      ...
# 62950  mtoControl   130.0   boss
# 62951     bob_ins   155.0    seq
# 62952     bob_ins   155.0    seq
# 62953     bob_ins   155.0    seq
# 62954     bob_ins   155.0    seq
#
#                                                  logtext  trace_id
# 60067  MATISSE_img_acq -- Celestial target acquisitio...         9
# 60068        Started at 2019-04-10T02:29:03 (underlined)         9
# 60069                          DET1 WLMINCUT VAL = '3.0'         9
# 60070                        COU AG GSSOURCE = 'SCIENCE'         9
# 60071                              COU AG EPOCH = '2000'         9
# ...                                                  ...       ...
# 62950                                SETUP command done.         9
# 62951                                  -1 (SpringGreen4)         9
# 62952                 Template MATISSE_img_acq finished.         9
# 62953  Finished in 334 seconds at 2019-04-10T02:34:37...         9
# 62954  TplExecTimeStats: TPL.ID MATISSE_img_acq  esti...         9
#
# [2888 rows x 14 columns]

# %%
Base.meta_data['Trace_tokens'][0]
# Out:
# [['Started', 'at', 'underlined'],
#  ['Celestial', 'target', 'acquisition', 'yellow'],
#  ['COU', 'AG', 'ALPHA'],
#  ['SNRLIMIT', 'VAL'],
#  ['INTERFX', 'VAL'],
#  ['NCOHERENT', 'VAL'],
#  ['READ', 'CURNAME', 'SCI', 'HIGH', 'GAIN'],
#  ['WLMAXCUT', 'VAL'],
#  ['APOX', 'VAL'],
#  ['SNRLIMIT', 'VAL'],
#  ['NINCOHERENT', 'VAL'],
#  ['INTERFX', 'VAL'],
#  ['COU', 'AG', 'GSSOURCE', 'SCIENCE'],
#  ['COU', 'AG', 'EQUINOX'],
#  ['APOY', 'VAL'],
#  ['COU', 'AG', 'DELTA'],
#  ['READ', 'CURNAME', 'AUTO'],
#  ['WLMAXCUT', 'VAL'],
#  ['APOTYPE', 'VAL'],
#  ['INTERFY', 'VAL'],
#  ['DEL', 'REF', 'OPL'],
#  ['NINCOHERENT', 'VAL'],
#  ['NCOHERENT', 'VAL'],
#  ['COU', 'AG', 'PMA'],
#  ['COU', 'GS', 'MAG'],
#  ['COU', 'AG', 'PMD'],
#  ['WLMINCUT', 'VAL'],
#  ['APOY', 'VAL'],
#  ['COU', 'AG', 'EPOCH'],
#  ['APOTYPE', 'VAL'],
#  ['DEL', 'REF', 'MODE', 'AUTO'],
#  ['COU', 'AG', 'TYPE'],
#  ['DEL', 'FT', 'SENSOR', 'MATISSE'],
#  ['DEL', 'REF', 'NAME'],
#  ['INTERFY', 'VAL'],
#  ['APOX', 'VAL'],
#  ['SEQ', 'SIMUL', 'ST', 'F'],
#  ['SEQ', 'SKY', 'OFFS', 'DELTA'],
#  ['SEQ', 'LADC', 'ST', 'AUTO'],
#  ['SEQ', 'OPDM', 'L', 'WLMAX'],
#  ['SEQ', 'FS', 'INS', 'DIL', 'NAME', 'MED'],
#  ['SEQ', 'PUP', 'SKY', 'DURATION'],
#  ['SEQ', 'PUP', 'TARG', 'DURATION'],
#  ['SEQ', 'FS', 'TARG', 'DURATION'],
#  ['SEQ', 'ACQ', 'SKY', 'DURATION'],
#  ['SEQ', 'PUP', 'ST', 'F'],
#  ['SEQ', 'ACQ', 'INS', 'FIL', 'NAME', 'L'],
#  ['SEQ', 'ACQ', 'DIT'],
#  ['WLMINCUT', 'VAL'],
#  ['SEQ', 'FS', 'INS', 'FIL', 'NAME', 'LM'],
#  ['SEQ', 'OPDM', 'L', 'ST', 'T'],
#  ['SEQ', 'FS', 'ST', 'F'],
#  ['DPR', 'CATG', 'ACQUISITION'],
#  ['SEQ', 'OPDM', 'NSTEPS', 'AUTO'],
#  ['SEQ', 'PUP', 'DIT'],
#  ['SEQ', 'ACQ', 'TARG', 'DURATION'],
#  ['SEQ', 'FS', 'DIT', 'AUTO'],
#  ['SEQ', 'ACQ', 'INS', 'FIN', 'NAME', 'N'],
#  ['SEQ', 'OPDM', 'N', 'ST', 'T'],
#  ['SEQ', 'SKY', 'OFFS', 'ALPHA'],
#  ['SEQ', 'FS', 'DIT'],
#  ['SEQ', 'FS', 'INS', 'DIN', 'NAME', 'LOW'],
#  ['SEQ', 'FS', 'INS', 'SFL', 'NAME'],
#  ['SEQ', 'FS', 'INS', 'SFN', 'NAME'],
#  ['SEQ', 'DIL'],
#  ['SEQ', 'PRESET', 'ST', 'T'],
#  ['SEQ', 'FS', 'INS', 'FIN', 'NAME', 'OPEN'],
#  ['SEQ', 'ACQ', 'DIT'],
#  ['SEQ', 'FS', 'SKY', 'DURATION'],
#  ['SEQ', 'ACQ', 'ST', 'F'],
#  ['SEQ', 'CHOP', 'ST', 'T'],
#  ['SEQ', 'OPDM', 'N', 'WLMAX'],
#  ['SEQ', 'OSF', 'AUTO', 'T'],
#  ['SEQ', 'TADC', 'ST', 'AUTO'],
#  ['SEQ', 'TRACK', 'BAND', 'L'],
#  ['TEL', 'TARG', 'PMD'],
#  ['TEL', 'TARG', 'DELTA'],
#  ['TEL', 'MAG'],
#  ['SEQ', 'TARG', 'MAG', 'K'],
#  ['TEL', 'TARG', 'PMA'],
#  ['TEL', 'TARG', 'ALPHA'],
#  ['TEL', 'TARG', 'ADDVELDELTA'],
#  ['TEL', 'CHOP', 'PVRATIO'],
#  ['TEL', 'CHOP', 'POSANG'],
#  ['TEL', 'TARG', 'EQUINOX'],
#  ['TEL', 'DELTA'],
#  ['TEL', 'ALPHA'],
#  ['TEL', 'CHOP', 'THROW'],
#  ['TEL', 'TARG', 'ADDVELALPHA'],
#  ['SEQ', 'TARG', 'FLUX', 'L'],
#  ['SEQ', 'TRACK', 'ST', 'T'],
#  ['SEQ', 'TARG', 'FLUX', 'N'],
#  ['TEL', 'CHOP', 'FREQ'],
#  ['UNFORSEEN', 'No', 'OBS', 'AIRMASS', 'available'],
#  ['UNFORSEEN', 'No', 'OBS', 'WAVELEN', 'available'],
#  ['CDP', 'Received', 'command', 'GETCONF', 'Buffer'],
#  ['CDP',
#   'Succesfully',
#   'completed',
#   'command',
#   'GETCONF',
#   'Buffer',
#   'IRIS',
#   'compressed',
#   'compressed'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['LGSF', 'database', 'path', 'not', 'configured'],
#  ['LGSF', 'database', 'path', 'not', 'configured'],
#  ['enviroment',
#   'data',
#   'at',
#   'least',
#   'one',
#   'ASM',
#   'parameter',
#   'out',
#   'of',
#   'range'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['WD', 'scheduler', 'is', 'OK'],
#  ['WD', 'checking', 'scheduler', 's', 'health'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['TIF', 'Received', 'command', 'GETDELD', 'Buffer'],
#  ['TIF',
#   'Succesfully',
#   'completed',
#   'command',
#   'GETDELD',
#   'Buffer',
#   'DEFAULT'],
#  ['WD', 'scheduler', 'is', 'OK'],
#  ['WD', 'checking', 'scheduler', 's', 'health'],
#  [],
#  ['READ',
#   'CURNAME',
#   'in',
#   'AUTO',
#   'mode',
#   'set',
#   'to',
#   'SCI',
#   'SLOW',
#   'SPEED'],
#  ['SEQ', 'TADC', 'ST', 'in', 'AUTO', 'mode', 'set', 'to', 'F'],
#  ['Pressure', 'hPa', 'RH'],
#  ['Pointing', 'vector'],
#  ['IP', 'of', 'ref', 'beam', 'is'],
#  ['Origin', 'for', 'baselines'],
#  ['MATISSE', 'beam', 'tel', 'coordinates'],
#  ['Temperature', 'K'],
#  ['Air', 'index', 'L', 'band'],
#  ['Air', 'index', 'N', 'band'],
#  ['External', 'delay', 'm', 'Diff', 'OPD'],
#  ['MATISSE', 'beam', 'tel', 'coordinates'],
#  ['Temperature', 'K'],
#  ['Air', 'index', 'L', 'band'],
#  ['Air', 'index', 'N', 'band'],
#  ['External', 'delay', 'm', 'Diff', 'OPD'],
#  ['MATISSE', 'beam', 'tel', 'coordinates'],
#  ['Temperature', 'K'],
#  ['Air', 'index', 'L', 'band'],
#  ['Air', 'index', 'N', 'band'],
#  ['External', 'delay', 'm', 'Diff', 'OPD'],
#  ['MATISSE', 'beam', 'tel', 'coordinates'],
#  ['Temperature', 'K'],
#  ['Air', 'index', 'L', 'band'],
#  ['Air', 'index', 'N', 'band'],
#  ['External', 'delay', 'm', 'Diff', 'OPD'],
#  ['GetAutoLADC', 'max', 'ODP'],
#  ['SEQ', 'LADC', 'ST', 'in', 'AUTO', 'mode', 'set', 'to', 'F'],
#  ['SEQ', 'FS', 'DIT', 'in', 'AUTO', 'mode', 'set', 'to'],
#  ['SEQ', 'OPDM', 'NSTEPS', 'in', 'AUTO', 'mode', 'set', 'to'],
#  [],
#  ['WLMINCUT', 'VAL', 'set', 'to'],
#  ['WLMAXCUT', 'VAL', 'set', 'to'],
#  [],
#  ['WLMINCUT', 'VAL', 'set', 'to'],
#  ['WLMAXCUT', 'VAL', 'set', 'to'],
#  ['SETUP', 'noExposure', 'function', 'START', 'VAL', 'START', 'VAL', 'blue'],
#  ['Executing', 'SETUP', 'command'],
#  ['Forward', 'b', 'SETUP', 'to'],
#  ['Forward', 'b', 'SETUP', 'to'],
#  ['SETUP', 'command', 'done'],
#  [],
#  ['Interaction',
#   'simulation',
#   'delay',
#   'set',
#   'to',
#   'seconds',
#   'from',
#   'SetInteractionSimDelay',
#   'of',
#   'mtoseqUIF',
#   'BobTPL',
#   'uif',
#   'Blue'],
#  ['beginning', 'exposure', 'of', 'underlined'],
#  ['Executing', 'SETUP', 'command'],
#  ['SETUP', 'expoId', 'function', 'INS', 'MODE', 'HYBRID', 'blue'],
#  ['SETUP', 'command', 'done'],
#  [],
#  ['Executing', 'SETUP', 'command'],
#  ['SETUP',
#   'expoId',
#   'function',
#   'INS',
#   'MODE',
#   'HYBRID',
#   'INS',
#   'ST',
#   'T',
#   'INS',
#   'ST',
#   'T',
#   'INS',
#   'ST',
#   'T',
#   'INS',
#   'ST',
#   'T',
#   'blue'],
#  ['L', 'M', 'BSL', 'shutter', 'opened'],
#  ['TIF',
#   'Succesfully',
#   'completed',
#   'command',
#   'GETDELD',
#   'Buffer',
#   'DEFAULT'],
#  ['TIF', 'Received', 'command', 'GETDELD', 'Buffer'],
#  ['L', 'M', 'BSL', 'shutter', 'opened'],
#  ['L', 'M', 'BSL', 'shutter', 'opened'],
#  ['L', 'M', 'BSL', 'shutter', 'opened'],
#  ['SETUP', 'command', 'done'],
#  [],
#  ['Executing', 'SETUP', 'command'],
#  ['SETUP',
#   'expoId',
#   'function',
#   'INS',
#   'MODE',
#   'HYBRID',
#   'INS',
#   'ST',
#   'T',
#   'INS',
#   'ST',
#   'T',
#   'INS',
#   'ST',
#   'T',
#   'INS',
#   'ST',
#   'T',
#   'blue'],
#  ['TIF',
#   'Succesfully',
#   'completed',
#   'command',
#   'GETDELD',
#   'Buffer',
#   'DEFAULT'],
#  ['TIF', 'Received', 'command', 'GETDELD', 'Buffer'],
#  ['Motion', 'execution'],
#  ['TIF', 'Received', 'command', 'GETDELD', 'Buffer'],
#  ['TIF',
#   'Succesfully',
#   'completed',
#   'command',
#   'GETDELD',
#   'Buffer',
#   'DEFAULT'],
#  ['Motor', 'offset', 'done'],
#  ['Motion', 'execution'],
#  ['Motion', 'execution'],
#  ['N', 'BSN', 'shutter', 'opened'],
#  ['N', 'BSN', 'shutter', 'opened'],
#  ['N', 'BSN', 'shutter', 'opened'],
#  ['N', 'BSN', 'shutter', 'opened'],
#  ['SETUP', 'command', 'done'],
#  [],
#  ['Send',
#   'command',
#   'CHKMOON',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['CDP', 'Received', 'command', 'CHKMOON', 'Buffer'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'CHKMOON',
#   'id'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'CHKMOON', 'Buffer', 'OK'],
#  ['Motor', 'offset', 'done'],
#  ['Motion', 'execution'],
#  ['Motor', 'offset', 'done'],
#  ['Motor', 'offset', 'done'],
#  ['TIF',
#   'Succesfully',
#   'completed',
#   'command',
#   'GETDELD',
#   'Buffer',
#   'DEFAULT'],
#  ['TIF', 'Received', 'command', 'GETDELD', 'Buffer'],
#  ['WD', 'scheduler', 'is', 'OK'],
#  ['WD', 'checking', 'scheduler', 's', 'health'],
#  ['Last', 'reply', 'to', 'command', 'CHKMOON', 'id', 'received'],
#  ['Check', 'whether', 'VLTI', 'is', 'Lab', 'Guiding', 'brown'],
#  ['Send',
#   'command',
#   'GETIAS',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'GETIAS',
#   'id'],
#  ['CDP', 'Received', 'command', 'GETIAS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETIAS', 'Buffer', 'IRIS'],
#  ['Last', 'reply', 'to', 'command', 'GETIAS', 'id', 'received'],
#  ['Send',
#   'command',
#   'GETIAS',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'GETIAS',
#   'id'],
#  ['CDP', 'Received', 'command', 'GETIAS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETIAS', 'Buffer', 'IRIS'],
#  ['Last', 'reply', 'to', 'command', 'GETIAS', 'id', 'received'],
#  ['IAS', 'IRIS'],
#  ['Send',
#   'command',
#   'STOPLAG',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'STOPLAG',
#   'id'],
#  ['CDP', 'Received', 'command', 'STOPLAG', 'Buffer'],
#  ['Send', 'command', 'STOPLAG', 'to', 'sub', 'system', 'IRIS'],
#  ['Last', 'Reply', 'to', 'STOPLAG', 'from', 'IRIS', 'received', 'OK', 'len'],
#  ['Stop', 'before', 'starting', 'the', 'data', 'saving'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'STOPLAG', 'Buffer', 'OK'],
#  ['TIF', 'Received', 'command', 'GETDELD', 'Buffer'],
#  ['TIF',
#   'Succesfully',
#   'completed',
#   'command',
#   'GETDELD',
#   'Buffer',
#   'DEFAULT'],
#  ['Last', 'reply', 'to', 'command', 'STOPLAG', 'id', 'received'],
#  ['Set', 'MATISSE', 'default', 'reference', 'pixel', 'brown'],
#  ['Send',
#   'command',
#   'SETPOF',
#   'MATISSE',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['CDP', 'Received', 'command', 'SETPOF', 'Buffer', 'MATISSE'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'SETPOF',
#   'id'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'SETPOF', 'Buffer', 'OK'],
#  ['Last', 'reply', 'to', 'command', 'SETPOF', 'id', 'received'],
#  ['V', 'W'],
#  ['Send',
#   'command',
#   'SETPOF',
#   'MATISSE',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'SETPOF',
#   'id'],
#  ['CDP', 'Received', 'command', 'SETPOF', 'Buffer', 'MATISSE'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'SETPOF', 'Buffer', 'OK'],
#  ['Last', 'reply', 'to', 'command', 'SETPOF', 'id', 'received'],
#  ['V', 'W'],
#  ['Send',
#   'command',
#   'SETPOF',
#   'MATISSE',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['CDP', 'Received', 'command', 'SETPOF', 'Buffer', 'MATISSE'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'SETPOF',
#   'id'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'SETPOF', 'Buffer', 'OK'],
#  ['Last', 'reply', 'to', 'command', 'SETPOF', 'id', 'received'],
#  ['V', 'W'],
#  ['Send',
#   'command',
#   'SETPOF',
#   'MATISSE',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['CDP', 'Received', 'command', 'SETPOF', 'Buffer', 'MATISSE'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'SETPOF',
#   'id'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'SETPOF', 'Buffer', 'OK'],
#  ['Last', 'reply', 'to', 'command', 'SETPOF', 'id', 'received'],
#  ['V', 'W'],
#  ['Send',
#   'command',
#   'SETTADC',
#   'ENABLED',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['CDP', 'Received', 'command', 'SETTADC', 'Buffer', 'ENABLED'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'SETTADC',
#   'id'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'SETTADC', 'Buffer', 'OK'],
#  ['Last', 'reply', 'to', 'command', 'SETTADC', 'id', 'received'],
#  ['SETUP',
#   'expoId',
#   'function',
#   'START',
#   'VAL',
#   'TPLID',
#   'VAL',
#   'START',
#   'VAL',
#   'TPLID',
#   'VAL',
#   'blue'],
#  ['Executing', 'SETUP', 'command'],
#  ['Forward', 'b', 'SETUP', 'to'],
#  ['Forward', 'b', 'SETUP', 'to'],
#  ['SETUP', 'command', 'done'],
#  [],
#  ['Start', 'VLTI', 'preset', 'underlined'],
#  ['Clear', 'ISS', 'setup', 'blue'],
#  ['Send',
#   'command',
#   'CLRSTP',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'CLRSTP',
#   'id'],
#  ['CDP', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['TIF', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['PRESET', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['TIF', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['PRESET', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['PRESET', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['TIF', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['TIF', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['PRESET', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['CONTROL', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['TIF', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['PRESET', 'Received', 'command', 'CLRSTP', 'Buffer'],
#  ['PRESET', 'Command', 'CLRSTP', 'NoMove', 'succesfully', 'completed'],
#  ['TIF', 'Succesfully', 'completed', 'command', 'CLRSTP', 'Buffer', 'OK'],
#  ['CONTROL', 'Command', 'CLRSTP', 'NoMove', 'succesfully', 'completed'],
#  ['PRESET', 'Command', 'STOPTRK', 'NoMove', 'succesfully', 'completed'],
#  ['TIF', 'Succesfully', 'completed', 'command', 'CLRSTP', 'Buffer', 'OK'],
#  ['PRESET', 'Command', 'STOPTRK', 'NoMove', 'succesfully', 'completed'],
#  ['TIF', 'Succesfully', 'completed', 'command', 'CLRSTP', 'Buffer', 'OK'],
#  ['PRESET', 'Command', 'STOPTRK', 'NoMove', 'succesfully', 'completed'],
#  ['TIF', 'Succesfully', 'completed', 'command', 'CLRSTP', 'Buffer', 'OK'],
#  ['TIF', 'Succesfully', 'completed', 'command', 'CLRSTP', 'Buffer', 'OK'],
#  ['PRESET', 'Command', 'STOPTRK', 'NoMove', 'succesfully', 'completed'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'CLRSTP', 'Buffer', 'OK'],
#  ['Last', 'reply', 'to', 'command', 'CLRSTP', 'id', 'received'],
#  ['Send',
#   'command',
#   'GETIAS',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['CDP', 'Received', 'command', 'GETIAS', 'Buffer'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'GETIAS',
#   'id'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETIAS', 'Buffer', 'IRIS'],
#  ['Last', 'reply', 'to', 'command', 'GETIAS', 'id', 'received'],
#  ['Stop', 'Lab', 'Guiding', 'blue'],
#  ['Send',
#   'command',
#   'GETIAS',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['CDP', 'Received', 'command', 'GETIAS', 'Buffer'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'GETIAS',
#   'id'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETIAS', 'Buffer', 'IRIS'],
#  ['Last', 'reply', 'to', 'command', 'GETIAS', 'id', 'received'],
#  ['IAS', 'IRIS'],
#  ['Send',
#   'command',
#   'STOPLAG',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'STOPLAG',
#   'id'],
#  ['CDP', 'Received', 'command', 'STOPLAG', 'Buffer'],
#  ['Send', 'command', 'STOPLAG', 'to', 'sub', 'system', 'IRIS'],
#  ['Last', 'Reply', 'to', 'STOPLAG', 'from', 'IRIS', 'received', 'OK', 'len'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'STOPLAG', 'Buffer', 'OK'],
#  ['AVC', 'Loop', 'opening'],
#  ['AO', 'Loop', 'opening'],
#  ['AVC', 'Loop', 'opening'],
#  ['AVC', 'Loop', 'opening'],
#  ['AO', 'Loop', 'opening'],
#  ['AO', 'Loop', 'opening'],
#  ['AVC', 'Loop', 'opening'],
#  ['AO', 'Loop', 'opening'],
#  ['Artificial', 'Source', 'Lamp', 'turned', 'off'],
#  ['Sent', 'Command', 'SETASM', 'to', 'alttrkServer', 'with'],
#  ['Sent', 'Command', 'SETASM', 'to', 'aztrkServer', 'with'],
#  ['Sent', 'Command', 'SETASM', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETASM', 'to', 'probetrkServer', 'with'],
#  ['Command', 'SETASM', 'completed', 'by', 'alttrkServer'],
#  ['Command', 'SETASM', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETASM', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETASM', 'completed', 'by', 'probetrkServer'],
#  ['Last', 'reply', 'to', 'command', 'STOPLAG', 'id', 'received'],
#  ['Creating', 'Setup', 'Buffer'],
#  ['Adding', 'TEL', 'TARG', 'ALPHA'],
#  ['Adding', 'TEL', 'TARG', 'ADDVELALPHA'],
#  ['Adding', 'TEL', 'TARG', 'PMA'],
#  ['Adding', 'TEL', 'DELTA'],
#  ['Adding', 'TEL', 'CHOP', 'THROW'],
#  ['Adding', 'TEL', 'TARG', 'WLENGTH'],
#  ['Adding', 'TEL', 'TARG', 'PMD'],
#  ['Adding', 'TEL', 'ALPHA'],
#  ['Adding', 'TEL', 'CHOP', 'POSANG'],
#  ['Adding', 'TEL', 'CHOP', 'PVRATIO'],
#  ['Adding', 'TEL', 'TARG', 'EQUINOX'],
#  ['Adding', 'TEL', 'CHOP', 'FREQ'],
#  ['Adding', 'TEL', 'MAG'],
#  ['Adding', 'TEL', 'TARG', 'DELTA'],
#  ['Adding', 'TEL', 'TARG', 'ADDVELDELTA'],
#  ['Adding', 'COU', 'AG', 'ALPHA'],
#  ['Adding', 'COU', 'AG', 'DELTA'],
#  ['Adding', 'COU', 'AG', 'PMA'],
#  ['Adding', 'COU', 'AG', 'TYPE'],
#  ['Adding', 'COU', 'AG', 'EPOCH'],
#  ['Adding', 'COU', 'AG', 'GSSOURCE', 'SCIENCE'],
#  ['Adding', 'COU', 'GS', 'MAG'],
#  ['Adding', 'COU', 'AG', 'EQUINOX'],
#  ['Adding', 'COU', 'AG', 'PMD'],
#  ['Adding', 'DEL', 'FT', 'SENSOR', 'MATISSE'],
#  ['TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'ADDVELDELTA',
#   'COU',
#   'AG',
#   'ALPHA',
#   'COU',
#   'AG',
#   'DELTA',
#   'COU',
#   'AG',
#   'PMA',
#   'COU',
#   'AG',
#   'TYPE',
#   'COU',
#   'AG',
#   'EPOCH',
#   'COU',
#   'AG',
#   'GSSOURCE',
#   'SCIENCE'],
#  ['Send',
#   'command',
#   'SETUP',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'ADDVELALPHA',
#   'TEL',
#   'TARG',
#   'PMA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'CHOP',
#   'THROW'],
#  ['COU',
#   'GS',
#   'MAG',
#   'COU',
#   'AG',
#   'EQUINOX',
#   'COU',
#   'AG',
#   'PMD',
#   'DEL',
#   'FT',
#   'SENSOR',
#   'MATISSE',
#   'to',
#   'process',
#   'issifControl',
#   'env',
#   'wvgvlti'],
#  ['TEL',
#   'TARG',
#   'WLENGTH',
#   'TEL',
#   'TARG',
#   'PMD',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'CHOP',
#   'POSANG',
#   'TEL',
#   'CHOP',
#   'PVRATIO',
#   'TEL',
#   'TARG',
#   'EQUINOX',
#   'TEL',
#   'CHOP',
#   'FREQ',
#   'TEL',
#   'MAG'],
#  ['Command',
#   'SETUP',
#   'not',
#   'checked',
#   'sent',
#   'by',
#   'proc',
#   'issifControl',
#   'on',
#   'env',
#   'wvgvlti'],
#  ['Preset', 'to', 'VLTI', 'has', 'been', 'sent'],
#  ['CDP',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'ADDVELALPHA',
#   'TEL',
#   'TARG',
#   'PMA'],
#  ['CONTROL',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TA'],
#  ['Initial', 'instrument', 'setup', 'underlined'],
#  ['CONTROL',
#   'JIRA',
#   'VLTSW',
#   'COU',
#   'AG',
#   'ALPHA',
#   'DELTA',
#   'corrected',
#   'with',
#   'TEL',
#   'TARG',
#   'PMA',
#   'PMD'],
#  ['ACTION',
#   'Received',
#   'command',
#   'PRESET',
#   'Buffer',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TAR'],
#  ['INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC'],
#  ['INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'BCDA',
#   'IN',
#   'BCD',
#   'STATE',
#   'BCD',
#   'STATE'],
#  ['SETUP',
#   'expoId',
#   'file',
#   'ref',
#   'function',
#   'INS',
#   'MODE',
#   'HYBRID',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC'],
#  ['INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC'],
#  ['INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC'],
#  ['INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC'],
#  ['blue'],
#  ['INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC',
#   'INS',
#   'ENC'],
#  ['Executing', 'SETUP', 'command'],
#  ['Received', 'command', 'PRSNAME', 'Buffer', 'FREE'],
#  ['ACTION',
#   'Send',
#   'command',
#   'to',
#   'issprsCompAct',
#   'PRSNAME',
#   'Buffer',
#   'FREE'],
#  ['ACTION', 'Send', 'command', 'to', 'issprsDispatch', 'STOPCAG', 'Buffer'],
#  ['TIF', 'Received', 'command', 'STOPCAG', 'Buffer'],
#  ['TIF', 'Received', 'command', 'STOPCAG', 'Buffer'],
#  ['Forward', 'b', 'SETUP', 'to'],
#  ['Forward', 'b', 'SETUP', 'to'],
#  ['TIF', 'Received', 'command', 'STOPCAG', 'Buffer'],
#  ['Opening', 'AO', 'loop'],
#  ['TIF', 'Received', 'command', 'STOPCAG', 'Buffer'],
#  ['Opening', 'AO', 'loop'],
#  ['Opening', 'AO', 'loop'],
#  ['Opening', 'AO', 'loop'],
#  ['C', 'Changing', 'substate', 'from', 'IDLE', 'to', 'BUSY'],
#  ['cmd', 'finished'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'Warning'],
#  ['Initiate', 'new', 'telescope', 'position'],
#  ['cmd', 'finished'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'Normal'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'remtrkTimeAlarm', 'Warning'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'remtrkTimeAlarm', 'Normal'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'Normal'],
#  ['cmd', 'finished'],
#  ['Initiate', 'new', 'telescope', 'position'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'Warning'],
#  ['Next', 'INS', 'NO', 'for', 'next', 'move'],
#  ['Next', 'INS', 'NO', 'for', 'next', 'move'],
#  ['Motion', 'execution', 'of', 'the', 'BCD', 'device'],
#  ['Initiate', 'new', 'telescope', 'position'],
#  ['Initiate', 'new', 'telescope', 'position'],
#  ['cmd', 'finished'],
#  ['C', 'Changing', 'substate', 'from', 'BUSY', 'to', 'IDLE'],
#  ['TIF', 'Succesfully', 'completed', 'command', 'STOPCAG', 'Buffer', 'OK'],
#  ['NAOMI', 'loops', 'opened'],
#  ['NAOMI', 'loops', 'opened'],
#  ['TIF', 'Succesfully', 'completed', 'command', 'STOPCAG', 'Buffer', 'OK'],
#  ['NAOMI', 'loops', 'opened'],
#  ['TIF', 'Succesfully', 'completed', 'command', 'STOPCAG', 'Buffer', 'OK'],
#  ['NAOMI', 'loops', 'opened'],
#  ['TIF', 'Succesfully', 'completed', 'command', 'STOPCAG', 'Buffer', 'OK'],
#  ['ACTION', 'Send', 'command', 'to', 'issalignControl', 'STOPLAG', 'Buffer'],
#  ['Send', 'command', 'STOPLAG', 'to', 'sub', 'system', 'IRIS'],
#  ['Last', 'Reply', 'to', 'STOPLAG', 'from', 'IRIS', 'received', 'OK', 'len'],
#  ['ACTION', 'Send', 'command', 'to', 'issmswControl', 'PRESET', 'Buffer'],
#  ['TIF',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'EPOCH'],
#  ['PRESET',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TAR'],
#  ['TIF',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'EPOCH'],
#  ['PRESET',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TAR'],
#  ['TIF',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'EPOCH'],
#  ['PRESET',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TAR'],
#  ['TIF',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'EPOCH'],
#  ['PRESET',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TAR'],
#  ['TIF',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'DEL',
#   'TARG',
#   'TYPE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'EPOCH'],
#  ['PRESET',
#   'Received',
#   'command',
#   'SETUP',
#   'Buffer',
#   'DEL',
#   'TARG',
#   'TYPE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'EPOCH',
#   'TEL',
#   'TARG',
#   'EPOCHSYS'],
#  ['Executing', 'SETUP', 'command'],
#  ['Forward', 'b', 'SETUP', 'to', 'IRIS'],
#  ['Executing', 'SETUP', 'command'],
#  ['AUTO', 'GUIDE', 'Accepted', 'command', 'STOPAG', 'Buffer'],
#  ['AUTO', 'GUIDE', 'Succesfully', 'completed', 'Command', 'STOPAG', 'Buffer'],
#  ['TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'EPOCH',
#   'TEL',
#   'TARG',
#   'EPOCHSYSTEM',
#   'J',
#   'TEL',
#   'TARG',
#   'EQUINOX',
#   'TEL',
#   'TARG',
#   'PMA'],
#  ['POCH',
#   'ISS',
#   'PRI',
#   'PS',
#   'EPOCHSYSTEM',
#   'J',
#   'ISS',
#   'PRI',
#   'SS',
#   'EPOCHSYSTEM',
#   'J',
#   'ISS',
#   'PRI',
#   'PS',
#   'EQUINOX',
#   'ISS',
#   'PRI',
#   'SS',
#   'EQUINOX',
#   'ISS',
#   'PRI',
#   'PS',
#   'PMA',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMA',
#   'I'],
#  ['EL',
#   'AG',
#   'OBJCNT',
#   'F',
#   'TEL',
#   'AG',
#   'COUNT',
#   'TEL',
#   'AG',
#   'CYCLETIME',
#   'TEL',
#   'AG',
#   'INTTIME',
#   'TEL',
#   'AG',
#   'MAXMOVE',
#   'TEL',
#   'AG',
#   'PROBEPATH',
#   'F',
#   'TEL',
#   'AG',
#   'MINMAG',
#   'TEL',
#   'AG',
#   'MAXMAG',
#   'TEL',
#   'AG',
#   'MINRAD',
#   'T'],
#  ['TEL',
#   'TARG',
#   'PMD',
#   'TEL',
#   'TARG',
#   'RADVEL',
#   'TEL',
#   'TARG',
#   'PARALLAX',
#   'TEL',
#   'TARG',
#   'COORDTYPE',
#   'M',
#   'TEL',
#   'TARG',
#   'ALT',
#   'TEL',
#   'TARG',
#   'AZ',
#   'TEL',
#   'TARG',
#   'NAME',
#   'TEL',
#   'TARG',
#   'WLENGTH'],
#  ['COU',
#   'GS',
#   'WAVELEN',
#   'COU',
#   'AG',
#   'OBJCNT',
#   'F',
#   'COU',
#   'AO',
#   'START',
#   'T',
#   'ISS',
#   'PRI',
#   'PRESET',
#   'TYPE',
#   'TEL',
#   'AG',
#   'TYPE',
#   'TEL',
#   'AG',
#   'START',
#   'F',
#   'TEL',
#   'AG',
#   'GUIDESTAR',
#   'CATALOGUE',
#   'T'],
#  ['COU',
#   'AG',
#   'INTTIME',
#   'COU',
#   'GS',
#   'FWHM',
#   'COU',
#   'ACQ',
#   'MEASSKY',
#   'F',
#   'COU',
#   'ACQ',
#   'SKYMAG',
#   'ISS',
#   'PRI',
#   'PS',
#   'COORDTYPE',
#   'M',
#   'ISS',
#   'PRI',
#   'SS',
#   'COORDTYPE',
#   'M',
#   'ISS',
#   'PRI',
#   'PS',
#   'EPOCH',
#   'ISS',
#   'PRI',
#   'SS',
#   'E'],
#  ['SS',
#   'PRI',
#   'PS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'PS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'SS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'PS',
#   'PARALLAX',
#   'ISS',
#   'PRI',
#   'SS',
#   'PARALLAX',
#   'ISS',
#   'PRI',
#   'PS',
#   'WLENGTH'],
#  ['ISS',
#   'PRI',
#   'SS',
#   'WLENGTH',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'FREQ',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'THROW',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'PVRATIO',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'POSANG',
#   'ISS',
#   'PRI',
#   'PS',
#   'ALPHA',
#   'ISS',
#   'PRI',
#   'SS',
#   'ALPH'],
#  ['PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'AO',
#   'START',
#   'F',
#   'TEL',
#   'PSOUP',
#   'T',
#   'TEL',
#   'RESET',
#   'F',
#   'TEL',
#   'CHOP',
#   'FREQ',
#   'TEL',
#   'CHOP'],
#  ['A', 'ISS', 'PRI', 'PS', 'DELTA', 'ISS', 'PRI', 'SS', 'DELTA'],
#  ['TEL',
#   'TARG',
#   'OFFSETALPHA',
#   'TEL',
#   'TARG',
#   'OFFSETDELTA',
#   'TEL',
#   'TARG',
#   'ADDVELALPHA',
#   'TEL',
#   'TARG',
#   'ADDVELDELTA',
#   'TEL',
#   'ROT',
#   'PRSCRIT',
#   'TEL',
#   'ROT',
#   'OFFANGLE',
#   'TEL',
#   'ROT',
#   'ENABLED'],
#  ['Buffer', 'too', 'big', 'Size', 'Max', 'allowed', 'size', 'Buffer', 'Set'],
#  ['TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'G'],
#  ['EL',
#   'AG',
#   'MAXRAD',
#   'TEL',
#   'AG',
#   'F',
#   'TEL',
#   'AG',
#   'VIGLIM',
#   'NONE',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA'],
#  ['STS', 'SETUP', 'buffer'],
#  ['T',
#   'TEL',
#   'ROT',
#   'ALTAZTRACK',
#   'F',
#   'COU',
#   'AG',
#   'TYPE',
#   'COU',
#   'AG',
#   'START',
#   'F',
#   'COU',
#   'AG',
#   'GSSOURCE',
#   'SETUPFILE',
#   'COU',
#   'AG',
#   'OPTIMIZE',
#   'F',
#   'COU',
#   'AG',
#   'ALPHA',
#   'COU',
#   'AG',
#   'DELTA',
#   'COU',
#   'GS',
#   'MAG'],
#  ['THROW',
#   'TEL',
#   'CHOP',
#   'POSOPTIM',
#   'OFF',
#   'TEL',
#   'CHOP',
#   'PVRATIO',
#   'TEL',
#   'CHOP',
#   'TPAXIS',
#   'OFF',
#   'TEL',
#   'CHOP',
#   'POSANG',
#   'TEL',
#   'CHOP',
#   'OFFSCHOP',
#   'TEL',
#   'CHOP',
#   'GUIDE',
#   'A',
#   'COU',
#   'AG',
#   'COUNT',
#   'COU',
#   'AG',
#   'CYCLETIME'],
#  ['AUTO', 'GUIDE', 'Succesfully', 'completed', 'Command', 'STOPAG', 'Buffer'],
#  ['SETUP', 'command', 'done'],
#  ['AUTO', 'GUIDE', 'Accepted', 'command', 'STOPAG', 'Buffer'],
#  ['TEL',
#   'TARG',
#   'PMD',
#   'TEL',
#   'TARG',
#   'RADVEL',
#   'TEL',
#   'TARG',
#   'PARALLAX',
#   'TEL',
#   'TARG',
#   'COORDTYPE',
#   'M',
#   'TEL',
#   'TARG',
#   'ALT',
#   'TEL',
#   'TARG',
#   'AZ',
#   'TEL',
#   'TARG',
#   'NAME',
#   'TEL',
#   'TARG',
#   'WLENGTH'],
#  ['TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'EPOCH',
#   'TEL',
#   'TARG',
#   'EPOCHSYSTEM',
#   'J',
#   'TEL',
#   'TARG',
#   'EQUINOX',
#   'TEL',
#   'TARG',
#   'PMA'],
#  ['TEL',
#   'TARG',
#   'OFFSETALPHA',
#   'TEL',
#   'TARG',
#   'OFFSETDELTA',
#   'TEL',
#   'TARG',
#   'ADDVELALPHA',
#   'TEL',
#   'TARG',
#   'ADDVELDELTA',
#   'TEL',
#   'ROT',
#   'PRSCRIT',
#   'TEL',
#   'ROT',
#   'OFFANGLE',
#   'TEL',
#   'ROT',
#   'ENABLED'],
#  ['STS', 'SETUP', 'buffer'],
#  ['T',
#   'TEL',
#   'ROT',
#   'ALTAZTRACK',
#   'F',
#   'COU',
#   'AG',
#   'TYPE',
#   'COU',
#   'AG',
#   'START',
#   'F',
#   'COU',
#   'AG',
#   'GSSOURCE',
#   'SETUPFILE',
#   'COU',
#   'AG',
#   'OPTIMIZE',
#   'F',
#   'COU',
#   'AG',
#   'ALPHA',
#   'COU',
#   'AG',
#   'DELTA',
#   'COU',
#   'GS',
#   'MAG'],
#  ['Buffer', 'too', 'big', 'Size', 'Max', 'allowed', 'size', 'Buffer', 'Set'],
#  ['RSTLAG', 'command', 'done'],
#  ['EL',
#   'AG',
#   'MAXRAD',
#   'TEL',
#   'AG',
#   'F',
#   'TEL',
#   'AG',
#   'VIGLIM',
#   'NONE',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'alttrkServer', 'with'],
#  ['TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'G'],
#  ['COU',
#   'AG',
#   'INTTIME',
#   'COU',
#   'GS',
#   'FWHM',
#   'COU',
#   'ACQ',
#   'MEASSKY',
#   'F',
#   'COU',
#   'ACQ',
#   'SKYMAG',
#   'ISS',
#   'PRI',
#   'PS',
#   'COORDTYPE',
#   'M',
#   'ISS',
#   'PRI',
#   'SS',
#   'COORDTYPE',
#   'M',
#   'ISS',
#   'PRI',
#   'PS',
#   'EPOCH',
#   'ISS',
#   'PRI',
#   'SS',
#   'E'],
#  ['PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'AO',
#   'START',
#   'F',
#   'TEL',
#   'PSOUP',
#   'T',
#   'TEL',
#   'RESET',
#   'F',
#   'TEL',
#   'CHOP',
#   'FREQ',
#   'TEL',
#   'CHOP'],
#  ['COU',
#   'GS',
#   'WAVELEN',
#   'COU',
#   'AG',
#   'OBJCNT',
#   'F',
#   'COU',
#   'AO',
#   'START',
#   'T',
#   'ISS',
#   'PRI',
#   'PRESET',
#   'TYPE',
#   'TEL',
#   'AG',
#   'TYPE',
#   'TEL',
#   'AG',
#   'START',
#   'F',
#   'TEL',
#   'AG',
#   'GUIDESTAR',
#   'CATALOGUE',
#   'T'],
#  ['EL',
#   'AG',
#   'OBJCNT',
#   'F',
#   'TEL',
#   'AG',
#   'COUNT',
#   'TEL',
#   'AG',
#   'CYCLETIME',
#   'TEL',
#   'AG',
#   'INTTIME',
#   'TEL',
#   'AG',
#   'MAXMOVE',
#   'TEL',
#   'AG',
#   'PROBEPATH',
#   'F',
#   'TEL',
#   'AG',
#   'MINMAG',
#   'TEL',
#   'AG',
#   'MAXMAG',
#   'TEL',
#   'AG',
#   'MINRAD',
#   'T'],
#  ['POCH',
#   'ISS',
#   'PRI',
#   'PS',
#   'EPOCHSYSTEM',
#   'J',
#   'ISS',
#   'PRI',
#   'SS',
#   'EPOCHSYSTEM',
#   'J',
#   'ISS',
#   'PRI',
#   'PS',
#   'EQUINOX',
#   'ISS',
#   'PRI',
#   'SS',
#   'EQUINOX',
#   'ISS',
#   'PRI',
#   'PS',
#   'PMA',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMA',
#   'I'],
#  ['ISS',
#   'PRI',
#   'SS',
#   'WLENGTH',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'FREQ',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'THROW',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'PVRATIO',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'POSANG',
#   'ISS',
#   'PRI',
#   'PS',
#   'ALPHA',
#   'ISS',
#   'PRI',
#   'SS',
#   'ALPH'],
#  ['SS',
#   'PRI',
#   'PS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'PS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'SS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'PS',
#   'PARALLAX',
#   'ISS',
#   'PRI',
#   'SS',
#   'PARALLAX',
#   'ISS',
#   'PRI',
#   'PS',
#   'WLENGTH'],
#  ['THROW',
#   'TEL',
#   'CHOP',
#   'POSOPTIM',
#   'OFF',
#   'TEL',
#   'CHOP',
#   'PVRATIO',
#   'TEL',
#   'CHOP',
#   'TPAXIS',
#   'OFF',
#   'TEL',
#   'CHOP',
#   'POSANG',
#   'TEL',
#   'CHOP',
#   'OFFSCHOP',
#   'TEL',
#   'CHOP',
#   'GUIDE',
#   'A',
#   'COU',
#   'AG',
#   'COUNT',
#   'COU',
#   'AG',
#   'CYCLETIME'],
#  ['A', 'ISS', 'PRI', 'PS', 'DELTA', 'ISS', 'PRI', 'SS', 'DELTA'],
#  ['SETUP', 'command', 'done'],
#  ['CoordType', 'not', 'B', 'coordinates', 'before', 'Precces', 'coor'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'alttrkServer', 'with'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'aztrkServer', 'with'],
#  ['CoordType', 'not', 'B', 'coordinates', 'before', 'Precces', 'coor'],
#  ['AUTO', 'GUIDE', 'Succesfully', 'completed', 'Command', 'STOPAG', 'Buffer'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'aztrkServer', 'with'],
#  ['AUTO', 'GUIDE', 'Accepted', 'command', 'STOPAG', 'Buffer'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'probetrkServer', 'with'],
#  ['J',
#   'ISS',
#   'PRI',
#   'SS',
#   'EQUINOX',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMA',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'SS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'SS',
#   'PARALLAX',
#   'ISS',
#   'PRI',
#   'SS',
#   'WLENGTH',
#   'TEL',
#   'AG',
#   'TYPE',
#   'FI'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'probetrkServer', 'with'],
#  ['PARALLAX',
#   'ISS',
#   'PRI',
#   'PS',
#   'WLENGTH',
#   'ISS',
#   'PRI',
#   'SS',
#   'ALPHA',
#   'ISS',
#   'PRI',
#   'SS',
#   'DELTA',
#   'ISS',
#   'PRI',
#   'SS',
#   'COORDTYPE',
#   'M',
#   'ISS',
#   'PRI',
#   'SS',
#   'EPOCH',
#   'ISS',
#   'PRI',
#   'SS',
#   'EPOCHSYSTEM'],
#  ['DTYPE',
#   'M',
#   'ISS',
#   'PRI',
#   'PS',
#   'EPOCH',
#   'ISS',
#   'PRI',
#   'PS',
#   'EPOCHSYSTEM',
#   'J',
#   'ISS',
#   'PRI',
#   'PS',
#   'EQUINOX',
#   'ISS',
#   'PRI',
#   'PS',
#   'PMA',
#   'ISS',
#   'PRI',
#   'PS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'PS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'PS'],
#  ['TEL',
#   'AG',
#   'START',
#   'F',
#   'TEL',
#   'AG',
#   'GUIDESTAR',
#   'CATALOGUE',
#   'TEL',
#   'AG',
#   'OBJCNT',
#   'F',
#   'TEL',
#   'AG',
#   'COUNT',
#   'TEL',
#   'AG',
#   'CYCLETIME',
#   'TEL',
#   'AG',
#   'INTTIME',
#   'TEL',
#   'AG',
#   'MAXMOVE',
#   'TEL',
#   'AG',
#   'PROBEPATH',
#   'F'],
#  ['TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL'],
#  ['TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'EPOCH',
#   'TEL',
#   'TARG',
#   'EPOCHSYSTEM',
#   'J',
#   'TEL',
#   'TARG',
#   'EQUINOX',
#   'TEL',
#   'TARG',
#   'PMA'],
#  ['ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'AO',
#   'START',
#   'F',
#   'TEL',
#   'PSOUP'],
#  ['STS', 'SETUP', 'buffer'],
#  ['TEL',
#   'AG',
#   'MINMAG',
#   'TEL',
#   'AG',
#   'MAXMAG',
#   'TEL',
#   'AG',
#   'MINRAD',
#   'TEL',
#   'AG',
#   'MAXRAD',
#   'TEL',
#   'AG',
#   'F',
#   'TEL',
#   'AG',
#   'VIGLIM',
#   'NONE',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG'],
#  ['TEL',
#   'TARG',
#   'OFFSETALPHA',
#   'TEL',
#   'TARG',
#   'OFFSETDELTA',
#   'TEL',
#   'TARG',
#   'ADDVELALPHA',
#   'TEL',
#   'TARG',
#   'ADDVELDELTA',
#   'TEL',
#   'ROT',
#   'PRSCRIT',
#   'TEL',
#   'ROT',
#   'OFFANGLE',
#   'TEL',
#   'ROT',
#   'ENABLED'],
#  ['Buffer', 'too', 'big', 'Size', 'Max', 'allowed', 'size', 'Buffer', 'Set'],
#  ['T',
#   'TEL',
#   'ROT',
#   'ALTAZTRACK',
#   'F',
#   'COU',
#   'AG',
#   'TYPE',
#   'COU',
#   'AG',
#   'START',
#   'F',
#   'COU',
#   'AG',
#   'GSSOURCE',
#   'SETUPFILE',
#   'COU',
#   'AG',
#   'OPTIMIZE',
#   'F',
#   'COU',
#   'AG',
#   'ALPHA',
#   'COU',
#   'AG',
#   'DELTA',
#   'COU',
#   'GS',
#   'MAG'],
#  ['TEL',
#   'TARG',
#   'PMD',
#   'TEL',
#   'TARG',
#   'RADVEL',
#   'TEL',
#   'TARG',
#   'PARALLAX',
#   'TEL',
#   'TARG',
#   'COORDTYPE',
#   'M',
#   'TEL',
#   'TARG',
#   'ALT',
#   'TEL',
#   'TARG',
#   'AZ',
#   'TEL',
#   'TARG',
#   'NAME',
#   'TEL',
#   'TARG',
#   'WLENGTH'],
#  ['COU',
#   'GS',
#   'WAVELEN',
#   'COU',
#   'AG',
#   'OBJCNT',
#   'F',
#   'COU',
#   'AO',
#   'START',
#   'T',
#   'ISS',
#   'PRI',
#   'PRESET',
#   'TYPE',
#   'ISS',
#   'PRI',
#   'PS',
#   'ALPHA',
#   'ISS',
#   'PRI',
#   'PS',
#   'DELTA',
#   'ISS',
#   'PRI',
#   'PS',
#   'COOR'],
#  ['T',
#   'TEL',
#   'RESET',
#   'F',
#   'TEL',
#   'CHOP',
#   'FREQ',
#   'TEL',
#   'CHOP',
#   'THROW',
#   'TEL',
#   'CHOP',
#   'POSOPTIM',
#   'OFF',
#   'TEL',
#   'CHOP',
#   'PVRATIO',
#   'TEL',
#   'CHOP',
#   'TPAXIS',
#   'OFF',
#   'TEL',
#   'CHOP',
#   'POSANG',
#   'TEL',
#   'CHOP',
#   'OFFSCHOP'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'probetrkServer', 'with'],
#  ['AUTO', 'GUIDE', 'Succesfully', 'completed', 'Command', 'STOPAG', 'Buffer'],
#  ['TEL',
#   'CHOP',
#   'GUIDE',
#   'A',
#   'COU',
#   'AG',
#   'COUNT',
#   'COU',
#   'AG',
#   'CYCLETIME',
#   'COU',
#   'AG',
#   'INTTIME',
#   'COU',
#   'GS',
#   'FWHM',
#   'COU',
#   'ACQ',
#   'MEASSKY',
#   'F',
#   'COU',
#   'ACQ',
#   'SKYMAG',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'FREQ',
#   'ISS'],
#  ['PRI',
#   'CHOP',
#   'THROW',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'PVRATIO',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'POSANG'],
#  ['AUTO', 'GUIDE', 'Accepted', 'command', 'STOPAG', 'Buffer'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'probetrkServer', 'with'],
#  ['STS', 'SETUP', 'buffer'],
#  ['COU',
#   'GS',
#   'WAVELEN',
#   'COU',
#   'AG',
#   'OBJCNT',
#   'F',
#   'COU',
#   'AO',
#   'START',
#   'T',
#   'ISS',
#   'PRI',
#   'PRESET',
#   'TYPE',
#   'TEL',
#   'AG',
#   'TYPE',
#   'TEL',
#   'AG',
#   'START',
#   'F',
#   'TEL',
#   'AG',
#   'GUIDESTAR',
#   'CATALOGUE',
#   'T'],
#  ['THROW',
#   'TEL',
#   'CHOP',
#   'POSOPTIM',
#   'OFF',
#   'TEL',
#   'CHOP',
#   'PVRATIO',
#   'TEL',
#   'CHOP',
#   'TPAXIS',
#   'OFF',
#   'TEL',
#   'CHOP',
#   'POSANG',
#   'TEL',
#   'CHOP',
#   'OFFSCHOP',
#   'TEL',
#   'CHOP',
#   'GUIDE',
#   'A',
#   'COU',
#   'AG',
#   'COUNT',
#   'COU',
#   'AG',
#   'CYCLETIME'],
#  ['TEL',
#   'TARG',
#   'PMD',
#   'TEL',
#   'TARG',
#   'RADVEL',
#   'TEL',
#   'TARG',
#   'PARALLAX',
#   'TEL',
#   'TARG',
#   'COORDTYPE',
#   'M',
#   'TEL',
#   'TARG',
#   'ALT',
#   'TEL',
#   'TARG',
#   'AZ',
#   'TEL',
#   'TARG',
#   'NAME',
#   'TEL',
#   'TARG',
#   'WLENGTH'],
#  ['CoordType', 'not', 'B', 'coordinates', 'before', 'Precces', 'coor'],
#  ['T',
#   'TEL',
#   'ROT',
#   'ALTAZTRACK',
#   'F',
#   'COU',
#   'AG',
#   'TYPE',
#   'COU',
#   'AG',
#   'START',
#   'F',
#   'COU',
#   'AG',
#   'GSSOURCE',
#   'SETUPFILE',
#   'COU',
#   'AG',
#   'OPTIMIZE',
#   'F',
#   'COU',
#   'AG',
#   'ALPHA',
#   'COU',
#   'AG',
#   'DELTA',
#   'COU',
#   'GS',
#   'MAG'],
#  ['TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'G'],
#  ['EL',
#   'AG',
#   'MAXRAD',
#   'TEL',
#   'AG',
#   'F',
#   'TEL',
#   'AG',
#   'VIGLIM',
#   'NONE',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA'],
#  ['PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'AO',
#   'START',
#   'F',
#   'TEL',
#   'PSOUP',
#   'T',
#   'TEL',
#   'RESET',
#   'F',
#   'TEL',
#   'CHOP',
#   'FREQ',
#   'TEL',
#   'CHOP'],
#  ['EL',
#   'AG',
#   'OBJCNT',
#   'F',
#   'TEL',
#   'AG',
#   'COUNT',
#   'TEL',
#   'AG',
#   'CYCLETIME',
#   'TEL',
#   'AG',
#   'INTTIME',
#   'TEL',
#   'AG',
#   'MAXMOVE',
#   'TEL',
#   'AG',
#   'PROBEPATH',
#   'F',
#   'TEL',
#   'AG',
#   'MINMAG',
#   'TEL',
#   'AG',
#   'MAXMAG',
#   'TEL',
#   'AG',
#   'MINRAD',
#   'T'],
#  ['Buffer', 'too', 'big', 'Size', 'Max', 'allowed', 'size', 'Buffer', 'Set'],
#  ['TEL',
#   'TARG',
#   'OFFSETALPHA',
#   'TEL',
#   'TARG',
#   'OFFSETDELTA',
#   'TEL',
#   'TARG',
#   'ADDVELALPHA',
#   'TEL',
#   'TARG',
#   'ADDVELDELTA',
#   'TEL',
#   'ROT',
#   'PRSCRIT',
#   'TEL',
#   'ROT',
#   'OFFANGLE',
#   'TEL',
#   'ROT',
#   'ENABLED'],
#  ['TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'EPOCH',
#   'TEL',
#   'TARG',
#   'EPOCHSYSTEM',
#   'J',
#   'TEL',
#   'TARG',
#   'EQUINOX',
#   'TEL',
#   'TARG',
#   'PMA'],
#  ['ISS',
#   'PRI',
#   'SS',
#   'WLENGTH',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'FREQ',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'THROW',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'PVRATIO',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'POSANG',
#   'ISS',
#   'PRI',
#   'PS',
#   'ALPHA',
#   'ISS',
#   'PRI',
#   'SS',
#   'ALPH'],
#  ['COU',
#   'AG',
#   'INTTIME',
#   'COU',
#   'GS',
#   'FWHM',
#   'COU',
#   'ACQ',
#   'MEASSKY',
#   'F',
#   'COU',
#   'ACQ',
#   'SKYMAG',
#   'ISS',
#   'PRI',
#   'PS',
#   'COORDTYPE',
#   'M',
#   'ISS',
#   'PRI',
#   'SS',
#   'COORDTYPE',
#   'M',
#   'ISS',
#   'PRI',
#   'PS',
#   'EPOCH',
#   'ISS',
#   'PRI',
#   'SS',
#   'E'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'alttrkServer', 'with'],
#  ['A', 'ISS', 'PRI', 'PS', 'DELTA', 'ISS', 'PRI', 'SS', 'DELTA'],
#  ['Command', 'SETSITE', 'completed', 'by', 'alttrkServer'],
#  ['SS',
#   'PRI',
#   'PS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'PS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'SS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'PS',
#   'PARALLAX',
#   'ISS',
#   'PRI',
#   'SS',
#   'PARALLAX',
#   'ISS',
#   'PRI',
#   'PS',
#   'WLENGTH'],
#  ['POCH',
#   'ISS',
#   'PRI',
#   'PS',
#   'EPOCHSYSTEM',
#   'J',
#   'ISS',
#   'PRI',
#   'SS',
#   'EPOCHSYSTEM',
#   'J',
#   'ISS',
#   'PRI',
#   'PS',
#   'EQUINOX',
#   'ISS',
#   'PRI',
#   'SS',
#   'EQUINOX',
#   'ISS',
#   'PRI',
#   'PS',
#   'PMA',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMA',
#   'I'],
#  ['Command', 'SETSITE', 'completed', 'by', 'alttrkServer'],
#  ['Command', 'SETSITE', 'completed', 'by', 'aztrkServer'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'alttrkServer', 'with'],
#  ['Command', 'SETSITE', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETSITE', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETSITE', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETSITE', 'completed', 'by', 'probetrkServer'],
#  ['CoordType', 'not', 'B', 'coordinates', 'before', 'Precces', 'coor'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'aztrkServer', 'with'],
#  ['Command', 'SETSITE', 'completed', 'by', 'probetrkServer'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'alttrkServer', 'with', 'CO'],
#  ['Command', 'SETSITE', 'completed', 'by', 'alttrkServer'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'alttrkServer', 'with', 'CO'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'aztrkServer', 'with'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'probetrkServer', 'with'],
#  ['Command', 'SETSITE', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETSITE', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETSITE', 'completed', 'by', 'probetrkServer'],
#  ['Sent', 'Command', 'SETSITE', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'aztrkServer', 'with', 'CO'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'aztrkServer', 'with', 'CO'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'probetrkServer', 'with', 'CO'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'probetrkServer', 'with', 'CO'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'probetrkServer', 'with', 'CO'],
#  ['Command', 'SETSITE', 'completed', 'by', 'alttrkServer'],
#  ['Command', 'SETSITE', 'completed', 'by', 'probetrkServer'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'probetrkServer', 'with', 'CO'],
#  ['Command', 'SETFOC', 'completed', 'by', 'alttrkServer'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'alttrkServer', 'with', 'CO'],
#  ['Command', 'SETFOC', 'completed', 'by', 'alttrkServer'],
#  ['Command', 'SETSITE', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETFOC', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETFOC', 'completed', 'by', 'aztrkServer'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'aztrkServer', 'with', 'CO'],
#  ['Command', 'SETFOC', 'completed', 'by', 'aztrkServer'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'probetrkServer', 'with', 'CO'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'probetrkServer', 'with', 'CO'],
#  ['Command', 'SETFOC', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETFOC', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETSITE', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETFOC', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETFOC', 'completed', 'by', 'alttrkServer'],
#  ['Sent', 'Command', 'SETROT', 'to', 'alttrkServer', 'with'],
#  ['Sent', 'Command', 'SETROT', 'to', 'alttrkServer', 'with'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'alttrkServer', 'with', 'CO'],
#  ['Command', 'SETFOC', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETFOC', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETFOC', 'completed', 'by', 'probetrkServer'],
#  ['wdline', 'LOCAL', 'alias', 'Warning'],
#  ['wdline', 'LOCAL', 'alias', 'remtrkTimeAlarm', 'Warning'],
#  ['wdline', 'LOCAL', 'alias', 'Warning'],
#  ['Sent', 'Command', 'SETROT', 'to', 'aztrkServer', 'with'],
#  ['Sent', 'Command', 'SETROT', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETROT', 'to', 'aztrkServer', 'with'],
#  ['Sent', 'Command', 'SETROT', 'to', 'alttrkServer', 'with'],
#  ['Sent', 'Command', 'SETROT', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETROT', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETROT', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'aztrkServer', 'with', 'CO'],
#  ['Command', 'SETROT', 'completed', 'by', 'alttrkServer'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'probetrkServer', 'with', 'CO'],
#  ['Sent', 'Command', 'SETROT', 'to', 'aztrkServer', 'with'],
#  ['Sent', 'Command', 'SETFOC', 'to', 'probetrkServer', 'with', 'CO'],
#  ['Sent', 'Command', 'SETROT', 'to', 'probetrkServer', 'with'],
#  ['Command', 'SETROT', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETROT', 'completed', 'by', 'alttrkServer'],
#  ['Command', 'SETROT', 'completed', 'by', 'probetrkServer'],
#  ['Sent', 'Command', 'SETROT', 'to', 'probetrkServer', 'with'],
#  ['Command', 'SETROT', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETROT', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETROT', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETFOC', 'completed', 'by', 'alttrkServer'],
#  ['Command', 'SETROT', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETROT', 'completed', 'by', 'alttrkServer'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'alttrkServer', 'with'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'alttrkServer', 'with'],
#  ['Command', 'SETROT', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETROT', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETFOC', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETROT', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETFOC', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETFOC', 'completed', 'by', 'probetrkServer'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'aztrkServer', 'with'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'aztrkServer', 'with'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'alttrkServer', 'with'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETROT', 'to', 'alttrkServer', 'with'],
#  ['Command', 'SETOAX', 'completed', 'by', 'alttrkServer'],
#  ['Command', 'SETOAX', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETOAX', 'completed', 'by', 'probetrkServer'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'aztrkServer', 'with'],
#  ['Command', 'SETOAX', 'completed', 'by', 'alttrkServer'],
#  ['Sent', 'Command', 'SETOAX', 'to', 'probetrkServer', 'with'],
#  ['Command', 'SETOAX', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETOAX', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETOAX', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETOAX', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETOAX', 'completed', 'by', 'alttrkServer'],
#  ['Sent', 'Command', 'SETROT', 'to', 'aztrkServer', 'with'],
#  ['Sent', 'Command', 'SETROT', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'SETROT', 'to', 'probetrkServer', 'with'],
#  ['Sent', 'Command', 'OBJSTAR', 'to', 'alttrkServer', 'with', 'J'],
#  ['Command', 'SETOAX', 'completed', 'by', 'probetrkServer'],
#  ['Command', 'SETOAX', 'completed', 'by', 'aztrkServer'],
#  ['Command', 'SETOAX', 'completed', 'by', 'probetrkServer'],
#  ['Sent', 'Command', 'OBJSTAR', 'to', 'alttrkServer', 'with', 'J'],
#  ['Command', 'SETROT', 'completed', 'by', 'alttrkServer'],
#  ['Sent', 'Command', 'OBJSTAR', 'to', 'aztrkServer', 'with', 'J'],
#  ['wdline', 'LOCAL', 'alias', 'Normal'],
#  ['wdline', 'LOCAL', 'alias', 'remtrkTimeAlarm', 'Normal'],
#  ['wdline', 'LOCAL', 'alias', 'Normal'],
# ...
#   'PS',
#   'PMA',
#   'ISS',
#   'PRI',
#   'PS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'PS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'PS'],
#  ['TEL',
#   'AG',
#   'MINMAG',
#   'TEL',
#   'AG',
#   'MAXMAG',
#   'TEL',
#   'AG',
#   'MINRAD',
#   'TEL',
#   'AG',
#   'MAXRAD',
#   'TEL',
#   'AG',
#   'F',
#   'TEL',
#   'AG',
#   'VIGLIM',
#   'NONE',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG'],
#  ['NAOMI', 'SETUP', 'buffer'],
#  ['COU',
#   'GS',
#   'WAVELEN',
#   'COU',
#   'AG',
#   'OBJCNT',
#   'F',
#   'COU',
#   'AO',
#   'START',
#   'T',
#   'ISS',
#   'PRI',
#   'PRESET',
#   'TYPE',
#   'ISS',
#   'PRI',
#   'PS',
#   'ALPHA',
#   'ISS',
#   'PRI',
#   'PS',
#   'DELTA',
#   'ISS',
#   'PRI',
#   'PS',
#   'COOR'],
#  ['J',
#   'ISS',
#   'PRI',
#   'SS',
#   'EQUINOX',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMA',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'SS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'SS',
#   'PARALLAX',
#   'ISS',
#   'PRI',
#   'SS',
#   'WLENGTH',
#   'TEL',
#   'AG',
#   'TYPE',
#   'FI'],
#  ['PRI',
#   'CHOP',
#   'THROW',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'PVRATIO',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'POSANG'],
#  ['TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL'],
#  ['PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'AO',
#   'START',
#   'F',
#   'TEL',
#   'PSOUP',
#   'T',
#   'TEL',
#   'RESET',
#   'F',
#   'TEL',
#   'CHOP',
#   'FREQ',
#   'TEL',
#   'CHOP'],
#  ['COU',
#   'AG',
#   'INTTIME',
#   'COU',
#   'GS',
#   'FWHM',
#   'COU',
#   'ACQ',
#   'MEASSKY',
#   'F',
#   'COU',
#   'ACQ',
#   'SKYMAG',
#   'ISS',
#   'PRI',
#   'PS',
#   'COORDTYPE',
#   'M',
#   'ISS',
#   'PRI',
#   'SS',
#   'COORDTYPE',
#   'M',
#   'ISS',
#   'PRI',
#   'PS',
#   'EPOCH',
#   'ISS',
#   'PRI',
#   'SS',
#   'E'],
#  ['TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'G'],
#  ['NAOMI', 'setup', 'started'],
#  ['TEL',
#   'TARG',
#   'PMD',
#   'TEL',
#   'TARG',
#   'RADVEL',
#   'TEL',
#   'TARG',
#   'PARALLAX',
#   'TEL',
#   'TARG',
#   'COORDTYPE',
#   'M',
#   'TEL',
#   'TARG',
#   'ALT',
#   'TEL',
#   'TARG',
#   'AZ',
#   'TEL',
#   'TARG',
#   'NAME',
#   'TEL',
#   'TARG',
#   'WLENGTH'],
#  ['ISS',
#   'PRI',
#   'SS',
#   'WLENGTH',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'FREQ',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'THROW',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'PVRATIO',
#   'ISS',
#   'PRI',
#   'CHOP',
#   'POSANG',
#   'ISS',
#   'PRI',
#   'PS',
#   'ALPHA',
#   'ISS',
#   'PRI',
#   'SS',
#   'ALPH'],
#  ['T',
#   'TEL',
#   'ROT',
#   'ALTAZTRACK',
#   'F',
#   'COU',
#   'AG',
#   'TYPE',
#   'COU',
#   'AG',
#   'START',
#   'F',
#   'COU',
#   'AG',
#   'GSSOURCE',
#   'SETUPFILE',
#   'COU',
#   'AG',
#   'OPTIMIZE',
#   'F',
#   'COU',
#   'AG',
#   'ALPHA',
#   'COU',
#   'AG',
#   'DELTA',
#   'COU',
#   'GS',
#   'MAG'],
#  ['COU',
#   'GS',
#   'WAVELEN',
#   'COU',
#   'AG',
#   'OBJCNT',
#   'F',
#   'COU',
#   'AO',
#   'START',
#   'T',
#   'ISS',
#   'PRI',
#   'PRESET',
#   'TYPE',
#   'TEL',
#   'AG',
#   'TYPE',
#   'TEL',
#   'AG',
#   'START',
#   'F',
#   'TEL',
#   'AG',
#   'GUIDESTAR',
#   'CATALOGUE',
#   'T'],
#  ['EL',
#   'AG',
#   'MAXRAD',
#   'TEL',
#   'AG',
#   'F',
#   'TEL',
#   'AG',
#   'VIGLIM',
#   'NONE',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA',
#   'TEL',
#   'MAG',
#   'TEL',
#   'PPOS',
#   'POS',
#   'TEL',
#   'ALPHA',
#   'TEL',
#   'DELTA'],
#  ['SS',
#   'PRI',
#   'PS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMD',
#   'ISS',
#   'PRI',
#   'PS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'SS',
#   'RADVEL',
#   'ISS',
#   'PRI',
#   'PS',
#   'PARALLAX',
#   'ISS',
#   'PRI',
#   'SS',
#   'PARALLAX',
#   'ISS',
#   'PRI',
#   'PS',
#   'WLENGTH'],
#  ['TEL',
#   'TARG',
#   'OFFSETALPHA',
#   'TEL',
#   'TARG',
#   'OFFSETDELTA',
#   'TEL',
#   'TARG',
#   'ADDVELALPHA',
#   'TEL',
#   'TARG',
#   'ADDVELDELTA',
#   'TEL',
#   'ROT',
#   'PRSCRIT',
#   'TEL',
#   'ROT',
#   'OFFANGLE',
#   'TEL',
#   'ROT',
#   'ENABLED'],
#  ['EL',
#   'AG',
#   'OBJCNT',
#   'F',
#   'TEL',
#   'AG',
#   'COUNT',
#   'TEL',
#   'AG',
#   'CYCLETIME',
#   'TEL',
#   'AG',
#   'INTTIME',
#   'TEL',
#   'AG',
#   'MAXMOVE',
#   'TEL',
#   'AG',
#   'PROBEPATH',
#   'F',
#   'TEL',
#   'AG',
#   'MINMAG',
#   'TEL',
#   'AG',
#   'MAXMAG',
#   'TEL',
#   'AG',
#   'MINRAD',
#   'T'],
#  ['POCH',
#   'ISS',
#   'PRI',
#   'PS',
#   'EPOCHSYSTEM',
#   'J',
#   'ISS',
#   'PRI',
#   'SS',
#   'EPOCHSYSTEM',
#   'J',
#   'ISS',
#   'PRI',
#   'PS',
#   'EQUINOX',
#   'ISS',
#   'PRI',
#   'SS',
#   'EQUINOX',
#   'ISS',
#   'PRI',
#   'PS',
#   'PMA',
#   'ISS',
#   'PRI',
#   'SS',
#   'PMA',
#   'I'],
#  ['TEL',
#   'TARG',
#   'TYPE',
#   'COORDINATE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG',
#   'DELTA',
#   'TEL',
#   'TARG',
#   'EPOCH',
#   'TEL',
#   'TARG',
#   'EPOCHSYSTEM',
#   'J',
#   'TEL',
#   'TARG',
#   'EQUINOX',
#   'TEL',
#   'TARG',
#   'PMA'],
#  ['THROW',
#   'TEL',
#   'CHOP',
#   'POSOPTIM',
#   'OFF',
#   'TEL',
#   'CHOP',
#   'PVRATIO',
#   'TEL',
#   'CHOP',
#   'TPAXIS',
#   'OFF',
#   'TEL',
#   'CHOP',
#   'POSANG',
#   'TEL',
#   'CHOP',
#   'OFFSCHOP',
#   'TEL',
#   'CHOP',
#   'GUIDE',
#   'A',
#   'COU',
#   'AG',
#   'COUNT',
#   'COU',
#   'AG',
#   'CYCLETIME'],
#  ['NAOMI', 'SETUP', 'buffer'],
#  ['A', 'ISS', 'PRI', 'PS', 'DELTA', 'ISS', 'PRI', 'SS', 'DELTA'],
#  ['WFS', 'MODE', 'Configuring', 'to', 'CLEAR', 'RMAG', 'Flux'],
#  ['WFS', 'MODE', 'Configuring', 'to', 'CLEAR', 'RMAG', 'Flux'],
#  ['Motor', 'offset', 'done'],
#  ['Motion', 'execution'],
#  ['Motor', 'offset', 'done'],
#  ['Motion', 'execution'],
#  ['Motor', 'offset', 'done'],
#  ['Motion', 'execution'],
#  ['Motor', 'offset', 'done'],
#  ['Motor', 'offset', 'done'],
#  ['Motor', 'offset', 'done'],
#  ['Motion', 'execution'],
#  ['Motion', 'execution'],
#  ['Motor', 'offset', 'done'],
#  ['Motor', 'offset', 'done'],
#  ['Motion', 'execution'],
#  ['STS', 'xi', 'eta', 'radius', 'theta', 'rad'],
#  ['STS', 'xi', 'eta', 'radius', 'theta', 'rad'],
#  ['STS', 'xi', 'eta', 'radius', 'theta', 'rad'],
#  ['STS', 'xi', 'eta', 'radius', 'theta', 'rad'],
#  ['STS', 'xi', 'eta', 'radius', 'theta', 'rad'],
#  ['STS', 'xi', 'eta', 'radius', 'theta', 'rad'],
#  ['STS', 'xi', 'eta', 'radius', 'theta', 'rad'],
#  ['STS', 'xi', 'eta', 'radius', 'theta', 'rad'],
#  ['Next', 'INS', 'ENC', 'for', 'next', 'move'],
#  ['Motion', 'execution', 'of', 'the', 'N', 'CPN', 'device'],
#  ['Next', 'INS', 'ENC', 'for', 'next', 'move'],
#  ['Next', 'INS', 'ENC', 'for', 'next', 'move'],
#  ['Motor', 'offset', 'done'],
#  ['Motor', 'offset', 'done'],
#  ['Next', 'INS', 'ENC', 'for', 'next', 'move'],
#  ['Motor', 'offset', 'done'],
#  ['Motor', 'offset', 'done'],
#  ['Motor', 'offset', 'done'],
#  ['Motor', 'offset', 'done'],
#  ['Motor', 'offset', 'done'],
#  ['STS', 'Offsets', 'FSMs', 'DER'],
#  ['STS', 'Preset', 'to', 'Star', 'B', 'RA', 'DEC', 'Star', 'A', 'RA', 'DEC'],
#  ['STS',
#   'Corrected',
#   'coord',
#   'Star',
#   'B',
#   'RA',
#   'DEC',
#   'Star',
#   'A',
#   'RA',
#   'DEC'],
#  ['STS',
#   'Corrected',
#   'coord',
#   'Star',
#   'B',
#   'RA',
#   'DEC',
#   'Star',
#   'A',
#   'RA',
#   'DEC'],
#  ['STS', 'Preset', 'to', 'Star', 'B', 'RA', 'DEC', 'Star', 'A', 'RA', 'DEC'],
#  ['STS', 'Offsets', 'FSMs', 'DER'],
#  ['STS', 'Offsets', 'Derotator', 'rad', 'FSMs', 'rad'],
#  ['STS', 'Orientation', 'South'],
#  ['STS', 'Preset', 'completed'],
#  ['STS', 'Pressure', 'bar', 'bar'],
#  ['STS', 'Offsets', 'FSMs', 'DER'],
#  ['STS',
#   'Corrected',
#   'coord',
#   'Star',
#   'B',
#   'RA',
#   'DEC',
#   'Star',
#   'A',
#   'RA',
#   'DEC'],
#  ['STS', 'Preset', 'to', 'Star', 'B', 'RA', 'DEC', 'Star', 'A', 'RA', 'DEC'],
#  ['STS',
#   'Corrected',
#   'coord',
#   'Star',
#   'B',
#   'RA',
#   'DEC',
#   'Star',
#   'A',
#   'RA',
#   'DEC'],
#  ['STS', 'Offsets', 'FSMs', 'DER'],
#  ['STS', 'Preset', 'to', 'Star', 'B', 'RA', 'DEC', 'Star', 'A', 'RA', 'DEC'],
#  ['STS', 'Orientation', 'South'],
#  ['STS', 'Offsets', 'Derotator', 'rad', 'FSMs', 'rad'],
#  ['STS', 'Preset', 'completed'],
#  ['STS', 'Pressure', 'bar', 'bar'],
#  ['STS', 'Offsets', 'Derotator', 'rad', 'FSMs', 'rad'],
#  ['STS', 'Orientation', 'South'],
#  ['STS', 'Preset', 'completed'],
#  ['STS', 'Pressure', 'bar', 'bar'],
#  ['STS', 'Offsets', 'Derotator', 'rad', 'FSMs', 'rad'],
#  ['STS', 'Pressure', 'bar', 'bar'],
#  ['STS', 'Orientation', 'South'],
#  ['STS', 'Preset', 'completed'],
#  ['Motion', 'execution', 'of', 'the', 'N', 'CPN', 'device'],
#  ['Motion', 'execution', 'of', 'the', 'N', 'CPN', 'device'],
#  ['Motion', 'execution', 'of', 'the', 'N', 'CPN', 'device'],
#  ['PRESET', 'All', 'tracking', 'VCMs', 'within', 'tolerance'],
#  ['GetRefDl', 'oplZero'],
#  ['AstroPreset', 'AUTO'],
#  ['AstroPreset', 'GetRefDl', 'returned', 'refDl', 'refOpl'],
#  ['AstroPreset', 'Auto', 'Ref', 'Opl', 'dl', 'oplMinTrj', 'oplMaxTrj'],
#  ['AstroPreset', 'Auto', 'Ref', 'Opl', 'dl', 'oplMinTrj', 'oplMaxTrj'],
#  ['AstroPreset', 'Auto', 'Ref', 'Opl', 'dl', 'oplMinTrj', 'oplMaxTrj'],
#  ['AstroPreset', 'added', 'shift', 'for', 'dl', 'total', 'shift'],
#  ['AstroPreset', 'calculated', 'refOpl'],
#  ['Looking', 'for', 'OPD', 'model', 'with', 'keywords', 'and'],
#  ['Calculate', 'setting', 'invertPointingModel', 'flag', 'to', 'true'],
#  ['Looking', 'for', 'OPD', 'model', 'with', 'keywords', 'and'],
#  ['Looking', 'for', 'OPD', 'model', 'with', 'keywords', 'and'],
#  ['Calculate', 'setting', 'invertPointingModel', 'flag', 'to', 'true'],
#  ['Looking', 'for', 'OPD', 'model', 'with', 'keywords', 'and'],
#  ['Calculate', 'setting', 'invertPointingModel', 'flag', 'to', 'true'],
#  ['Illegal', 'name', 'model', 'dat'],
#  ['Illegal', 'name', 'model', 'dat'],
#  ['StopPresetOKCB', 'start', 'of', 'sent', 'stopchop', 'success'],
#  ['StopPresetOKCB', 'end', 'of', 'sent', 'stopchop', 'success'],
#  ['CalcCB', 'have', 'to', 'invert', 'the', 'pointing', 'model'],
#  ['CalcCB', 'have', 'to', 'invert', 'the', 'pointing', 'model'],
#  ['CalcCB', 'have', 'to', 'invert', 'the', 'pointing', 'model'],
#  ['WD', 'checking', 'scheduler', 's', 'health'],
#  ['WD', 'scheduler', 'is', 'OK'],
#  ['CDP', 'Received', 'command', 'GETCONF', 'Buffer'],
#  ['CDP',
#   'Succesfully',
#   'completed',
#   'command',
#   'GETCONF',
#   'Buffer',
#   'IRIS',
#   'compressed',
#   'compressed'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['INS', 'Motion', 'completed'],
#  ['Absolute', 'trajectory', 'file', 'trj'],
#  ['Absolute', 'trajectory', 'file', 'trj'],
#  ['Absolute', 'trajectory', 'file', 'trj'],
#  ['Absolute', 'trajectory', 'file', 'trj'],
#  ['OBSERVE', 'START'],
#  ['OBSERVE', 'START'],
#  ['OBSERVE', 'START'],
#  ['OBSERVE', 'START'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Serious'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Serious'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Serious'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Serious'],
#  ['wdline', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Serious'],
#  ['wdline', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Serious'],
#  ['wdline', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Serious'],
#  ['wdline', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Serious'],
#  ['INS', 'Motion', 'completed'],
#  ['INS', 'Motion', 'completed'],
#  ['INS', 'Motion', 'completed'],
#  ['INS', 'Motion', 'completed'],
#  ['INS', 'Motion', 'completed'],
#  [],
#  ['SETUP', 'command', 'done'],
#  ['Wait', 'the', 'VLTI', 'preset', 'is', 'completed', 'underlined'],
#  ['Waiting',
#   'timeout',
#   'for',
#   'pending',
#   'replies',
#   'to',
#   'command',
#   'SETUP',
#   'id'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Normal'],
#  ['wdline', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Normal'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Normal'],
#  ['wdline', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Normal'],
#  ['Command', 'OBJSTAR', 'completed', 'by', 'alttrkServer'],
#  ['Command', 'OBJSTAR', 'completed', 'by', 'alttrkServer'],
#  ['Command', 'OBJSTAR', 'completed', 'by', 'alttrkServer'],
#  ['Command', 'OBJSTAR', 'completed', 'by', 'alttrkServer'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Normal'],
#  ['wdline', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Normal'],
#  ['NAOMI', 'setup', 'completed'],
#  ['done'],
#  ['NAOMI', 'SETUP'],
#  ['NAOMI', 'SETUP'],
#  ['NAOMI', 'setup', 'completed'],
#  ['done'],
#  ['NAOMI', 'SETUP'],
#  ['NAOMI', 'setup', 'completed'],
#  ['done'],
#  ['done'],
#  ['NAOMI', 'setup', 'completed'],
#  ['NAOMI', 'SETUP'],
#  ['CDP', 'Received', 'command', 'GETCONF', 'Buffer'],
#  ['CDP',
#   'Succesfully',
#   'completed',
#   'command',
#   'GETCONF',
#   'Buffer',
#   'IRIS',
#   'compressed',
#   'compressed'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['WD', 'scheduler', 'is', 'OK'],
#  ['WD', 'checking', 'scheduler', 's', 'health'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CalcCB', 'have', 'to', 'invert', 'the', 'pointing', 'model'],
#  ['Jump',
#   'in',
#   'UTC',
#   'time',
#   'or',
#   'illegal',
#   'UTC',
#   'time',
#   'actual',
#   'time',
#   'last',
#   'valid',
#   'time'],
#  ['CalcCB', 'have', 'to', 'invert', 'the', 'pointing', 'model'],
#  ['Merge', 'trajectory', 'trj'],
#  ['UNFORSEEN', 'No', 'OBS', 'WAVELEN', 'available'],
#  ['UNFORSEEN', 'No', 'OBS', 'AIRMASS', 'available'],
#  ['LGSF', 'database', 'path', 'not', 'configured'],
#  ['LGSF', 'database', 'path', 'not', 'configured'],
#  ['enviroment',
#   'data',
#   'at',
#   'least',
#   'one',
#   'ASM',
#   'parameter',
#   'out',
#   'of',
#   'range'],
#  ['WD', 'scheduler', 'is', 'OK'],
#  ['WD', 'checking', 'scheduler', 's', 'health'],
#  ['WD', 'scheduler', 'is', 'OK'],
#  ['WD', 'checking', 'scheduler', 's', 'health'],
#  ['CDP', 'Received', 'command', 'GETCONF', 'Buffer'],
#  ['CDP',
#   'Succesfully',
#   'completed',
#   'command',
#   'GETCONF',
#   'Buffer',
#   'IRIS',
#   'compressed',
#   'compressed'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['Querying', 'status', 'from', 'interlock', 'PLC'],
#  ['WD', 'scheduler', 'is', 'OK'],
#  ['WD', 'checking', 'scheduler', 's', 'health'],
#  ['CalcCB', 'have', 'to', 'invert', 'the', 'pointing', 'model'],
#  ['PRESET',
#   'Succesfully',
#   'completed',
#   'Command',
#   'SETUP',
#   'Buffer',
#   'DEL',
#   'TARG',
#   'TYPE',
#   'TEL',
#   'TARG',
#   'ALPHA',
#   'TEL',
#   'TARG'],
#  ['TIF', 'Succesfully', 'completed', 'command', 'SETUP', 'Buffer', 'OK'],
#  ['UNFORSEEN', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Normal'],
#  ['wdline', 'LOCAL', 'alias', 'oplRMSErrorMasked', 'Normal'],
#  ['Merge', 'trajectory', 'trj'],
#  ['WD', 'scheduler', 'is', 'OK'],
#  ['WD', 'checking', 'scheduler', 's', 'health'],
#  ['Merge', 'trajectory', 'trj'],
#  ['WD', 'scheduler', 'is', 'OK'],
#  ['WD', 'checking', 'scheduler', 's', 'health'],
#  ['CDP', 'Received', 'command', 'GETCONF', 'Buffer'],
#  ['CDP',
#   'Succesfully',
#   'completed',
#   'command',
#   'GETCONF',
#   'Buffer',
#   'IRIS',
#   'compressed',
#   'compressed'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Received', 'command', 'GETWCS', 'Buffer'],
#  ['CDP', 'Succesfully', 'completed', 'command', 'GETWCS', 'Buffer'],
#  ['Initiate', 'new', 'telescope', 'additional', 'velocity'],
#  ['Initiate', 'new', 'telescope', 'additional', 'velocity'],
#  ...]

# %%
Base.trace_tokenization()  # el tokenizador de trazas puede recibir argumetos en expresiones regulares para probar distíntos filtros
# Out:
# Execution time:  0.024202400003559887  Seconds
# 60067             [Celestial, target, acquisition, yellow]
# 60068                            [Started, at, underlined]
# 60069                                      [WLMINCUT, VAL]
# 60070                         [COU, AG, GSSOURCE, SCIENCE]
# 60071                                     [COU, AG, EPOCH]
#                                ...
# 62950                               [SETUP, command, done]
# 62951                                                   []
# 62952                                 [Template, finished]
# 62953              [Finished, in, seconds, at, underlined]
# 62954    [TplExecTimeStats, TPL, ID, estimated, real, d...
# Name: logtext, Length: 2888, dtype: object

# %%
Base.trace_tokenization(regexp=r'\D+')
# Out:
# Execution time:  0.0172131999861449  Seconds
# 60067    [MATISSE_img_acq -- Celestial target acquisiti...
# 60068          [Started at , -, -, T, :, :,  (underlined)]
# 60069                       [DET,  WLMINCUT VAL = ', ., ']
# 60070                        [COU AG GSSOURCE = 'SCIENCE']
# 60071                                [COU AG EPOCH = ', ']
#                                ...
# 62950                                [SETUP command done.]
# 62951                                [-,  (SpringGreen, )]
# 62952                 [Template MATISSE_img_acq finished.]
# 62953    [Finished in ,  seconds at , -, -, T, :, :,  (...
# 62954    [TplExecTimeStats: TPL.ID MATISSE_img_acq  est...
# Name: logtext, Length: 2888, dtype: object

# %%
Base.trace_tokenization(regexp=r'[a-zA-Z]+')
# Out:
# Execution time:  0.02167299995198846  Seconds
# 60067    [MATISSE, img, acq, Celestial, target, acquisi...
# 60068                         [Started, at, T, underlined]
# 60069                                 [DET, WLMINCUT, VAL]
# 60070                         [COU, AG, GSSOURCE, SCIENCE]
# 60071                                     [COU, AG, EPOCH]
#                                ...
# 62950                               [SETUP, command, done]
# 62951                                        [SpringGreen]
# 62952              [Template, MATISSE, img, acq, finished]
# 62953           [Finished, in, seconds, at, T, underlined]
# 62954    [TplExecTimeStats, TPL, ID, MATISSE, img, acq,...
# Name: logtext, Length: 2888, dtype: object

# %%
Base.trace_tokenization(regexp=r'\s+', gaps=True)
# Out:
# Execution time:  0.02972099999897182  Seconds
# 60067    [MATISSE_img_acq, --, Celestial, target, acqui...
# 60068     [Started, at, 2019-04-10T02:29:03, (underlined)]
# 60069                      [DET1, WLMINCUT, VAL, =, '3.0']
# 60070                    [COU, AG, GSSOURCE, =, 'SCIENCE']
# 60071                          [COU, AG, EPOCH, =, '2000']
#                                ...
# 62950                              [SETUP, command, done.]
# 62951                                 [-1, (SpringGreen4)]
# 62952               [Template, MATISSE_img_acq, finished.]
# 62953    [Finished, in, 334, seconds, at, 2019-04-10T02...
# 62954    [TplExecTimeStats:, TPL.ID, MATISSE_img_acq, e...
# Name: logtext, Length: 2888, dtype: object

# %%
logs = Base.trace_data.logtext.to_list()
logs  # err in 642

# %%
Base.trace_data[Base.trace_data['logtext'].str.contains('ERR_')][:5]
# Out:
#                    @timestamp system hostname  loghost logtype  envname  \
# 60164 2019-04-10 02:29:04.439    ISS  wvgvlti  wvgvlti     ERR  wvgvlti
# 60370 2019-04-10 02:29:15.665    ISS  wvgvlti  wvgvlti     ERR  wvgvlti
# 60458 2019-04-10 02:29:16.628    AT4  wat4tcs  wat4tcs     ERR  wat4tcs
# 60467 2019-04-10 02:29:16.631    AT3  wat3tcs  wat3tcs     ERR  wat3tcs
# 60501 2019-04-10 02:29:16.634    AT2  wat2tcs  wat2tcs     ERR  wat2tcs
#
#             procname  procid  module keywname keywvalue keywmask  \
# 60164  issmonControl    62.0  tcsmon
# 60370  issprsControl    22.0     evh
# 60458  atagwsControl    70.0    eccs
# 60467  atagwsControl    70.0    eccs
# 60501  atagwsControl    70.0    eccs
#
#                                                  logtext  trace_id
# 60164  tcsmonERR_ENVIRONMENT : enviroment data at lea...         9
# 60370  evhERR_CMD_NOT_CHECKED : Command SETUP not che...         9
# 60458  eccsERR_BUF_TOO_BIG : Buffer too big. Size: 70...         9
# 60467  eccsERR_BUF_TOO_BIG : Buffer too big. Size: 70...         9
# 60501  eccsERR_BUF_TOO_BIG : Buffer too big. Size: 70...         9

# %%
Base.load_trace(index=10)

# %%
Base.trace_data[Base.trace_data['logtext'].str.contains('ERR_')][:5]
# Out:
#                    @timestamp   system hostname  loghost logtype  envname  \
# 63160 2019-04-10 02:35:04.440      ISS  wvgvlti  wvgvlti     ERR  wvgvlti
# 63255 2019-04-10 02:36:04.440      ISS  wvgvlti  wvgvlti     ERR  wvgvlti
# 63388 2019-04-10 02:36:40.103  MATISSE      wmt      wmt     ERR  wvgvlti
# 63441 2019-04-10 02:37:04.441      ISS  wvgvlti  wvgvlti     ERR  wvgvlti
# 63537 2019-04-10 02:38:04.440      ISS  wvgvlti  wvgvlti     ERR  wvgvlti
#
#               procname  procid   module keywname keywvalue keywmask  \
# 63160    issmonControl    62.0   tcsmon
# 63255    issmonControl    62.0   tcsmon
# 63388  issalignControl    31.0  issalig
# 63441    issmonControl    62.0   tcsmon
# 63537    issmonControl    62.0   tcsmon
#
#                                                  logtext  trace_id
# 63160  tcsmonERR_ENVIRONMENT : enviroment data at lea...        10
# 63255  tcsmonERR_ENVIRONMENT : enviroment data at lea...        10
# 63388  issalignERR_EVT_TIMEOUT : TIMEOUT in sub-state...        10
# 63441  tcsmonERR_ENVIRONMENT : enviroment data at lea...        10
# 63537  tcsmonERR_ENVIRONMENT : enviroment data at lea...        10

# %%
Base.trace_data['logtype'].unique()
Base.trace_data[Base.trace_data['logtype'] == 'ERR'][:5]
# Out:
#                    @timestamp   system hostname  loghost logtype  envname  \
# 63160 2019-04-10 02:35:04.440      ISS  wvgvlti  wvgvlti     ERR  wvgvlti
# 63255 2019-04-10 02:36:04.440      ISS  wvgvlti  wvgvlti     ERR  wvgvlti
# 63388 2019-04-10 02:36:40.103  MATISSE      wmt      wmt     ERR  wvgvlti
# 63441 2019-04-10 02:37:04.441      ISS  wvgvlti  wvgvlti     ERR  wvgvlti
# 63537 2019-04-10 02:38:04.440      ISS  wvgvlti  wvgvlti     ERR  wvgvlti
#
#               procname  procid   module keywname keywvalue keywmask  \
# 63160    issmonControl    62.0   tcsmon
# 63255    issmonControl    62.0   tcsmon
# 63388  issalignControl    31.0  issalig
# 63441    issmonControl    62.0   tcsmon
# 63537    issmonControl    62.0   tcsmon
#
#                                                  logtext  trace_id
# 63160  tcsmonERR_ENVIRONMENT : enviroment data at lea...        10
# 63255  tcsmonERR_ENVIRONMENT : enviroment data at lea...        10
# 63388  issalignERR_EVT_TIMEOUT : TIMEOUT in sub-state...        10
# 63441  tcsmonERR_ENVIRONMENT : enviroment data at lea...        10
# 63537  tcsmonERR_ENVIRONMENT : enviroment data at lea...        10

# %%
# Buscar errores en logtype es equivalente a buscar la palabra ERR_ en el logtext
Base.trace_data[Base.trace_data['logtype'] == 'ERR'].equals(Base.trace_data[Base.trace_data['logtext'].str.contains('ERR_')])
# Out:
# True
